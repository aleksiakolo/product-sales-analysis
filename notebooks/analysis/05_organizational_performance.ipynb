# %%
# load required libraries
library(tidyverse)
library(janitor)
library(dplyr)
library(ggplot2)
library(skimr)
library(purrr)
library(lubridate)

source("../../R/apply_factors.R")
source("../../R/analysis_helpers.R")
source("../../R/temporal_helpers.R")
tables <- list(
  Orders   = readr::read_csv("../../data/processed/Orders.csv"),
  Returns  = readr::read_csv("../../data/processed/Returns.csv"),
  People   = readr::read_csv("../../data/processed/People.csv")
)
tables <- apply_factors(tables)
orders <- tables$Orders 
returns <- tables$Returns
people <- tables$People
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
# Rows: 51290 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): order_id, ship_mode, customer_name, segment, state, country, mark...
# dbl   (6): sales, quantity, discount, profit, shipping_cost, year
# date  (2): order_date, ship_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1173 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): order_id, market
# lgl (1): returned
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): person, region
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # Regional Accountability Overview

# %% [markdown]
# ### Q1. How does sales performance vary across regions managed by different individuals?

# %%
orders_with_managers <- orders %>%
    left_join(people, by = "region")

manager_sales_performance <- orders_with_managers %>%
    group_by(person, region) %>%
    summarise(
        total_sales = sum(sales),
        total_profit = sum(profit),
        n_orders = n(),
        .groups = "drop"
    ) %>%
    arrange(desc(total_sales))

manager_sales_performance
# Out:
#    person               region         total_sales total_profit n_orders
# 1  Anna Andreadi        Central        2822302.52  311403.98    11117
# 2  Chuck Magee          South          1600907.04  140355.77     6645
# 3  Jack Lebron          North          1248165.60  194597.95     4785
# 4  Anthony Jacobs       Oceania        1100184.61  121666.64     3487
# 5  Alejandro Ballentine Southeast Asia  884423.17   17852.33     3129
# 6  Shirley Daniels      North Asia      848309.78  165578.42     2338
# 7  NA                   EMEA            806161.31   43897.97     5029
# 8  Deborah Brumfield    Africa          783773.21   88871.63     4587
# 9  Nora Preis           Central Asia    752826.57  132480.19     2048
# 10 Matt Collister       West            725457.82  108418.45     3203
# 11 Kelly Williams       East            678781.24   91522.78     2848
# 12 Giulietta Dortch     Caribbean       324280.86   34571.32     1690
# 13 Nicole Hansen        Canada           66928.17   17817.39      384

# %% [markdown]
# ### Q2. Are differences in regional performance driven by order volume or order value?

# %%
manager_volume_value <- orders_with_managers %>%
    group_by(person, region) %>%
    summarise(
        total_sales = sum(sales),
        n_orders = n(),
        avg_order_value = total_sales / n_orders,
        .groups = "drop"
    ) %>%
    arrange(desc(total_sales))

manager_volume_value
# Out:
#    person               region         total_sales n_orders avg_order_value
# 1  Anna Andreadi        Central        2822302.52  11117    253.8727
# 2  Chuck Magee          South          1600907.04   6645    240.9190
# 3  Jack Lebron          North          1248165.60   4785    260.8497
# 4  Anthony Jacobs       Oceania        1100184.61   3487    315.5104
# 5  Alejandro Ballentine Southeast Asia  884423.17   3129    282.6536
# 6  Shirley Daniels      North Asia      848309.78   2338    362.8357
# 7  NA                   EMEA            806161.31   5029    160.3025
# 8  Deborah Brumfield    Africa          783773.21   4587    170.8684
# 9  Nora Preis           Central Asia    752826.57   2048    367.5911
# 10 Matt Collister       West            725457.82   3203    226.4932
# 11 Kelly Williams       East            678781.24   2848    238.3361
# 12 Giulietta Dortch     Caribbean       324280.86   1690    191.8822
# 13 Nicole Hansen        Canada           66928.17    384    174.2921

# %% [markdown]
# # Performance Consistency & Risk

# %% [markdown]
# ### Q3. Do regions managed by different individuals show similar stability over time?

# %%
manager_sales_over_time <- orders_with_managers %>%
    add_time_period("order_date", period = "year") %>%
    group_by(person, region, period) %>%
    summarise(
        total_sales = sum(sales),
        .groups = "drop"
    )

manager_stability <- manager_sales_over_time %>%
    group_by(person, region) %>%
    summarise(
        mean_sales = mean(total_sales),
        sd_sales = sd(total_sales),
        cv_sales = sd_sales / mean_sales,
        .groups = "drop"
    ) %>%
    arrange(desc(cv_sales))

manager_stability
# Out:
#    person               region         mean_sales sd_sales   cv_sales
# 1  Deborah Brumfield    Africa         195943.30   73162.611 0.3733866
# 2  Nicole Hansen        Canada          16732.04    6198.215 0.3704399
# 3  NA                   EMEA           201540.33   72417.679 0.3593210
# 4  Alejandro Ballentine Southeast Asia 221105.79   74567.090 0.3372462
# 5  Anthony Jacobs       Oceania        275046.15   83062.357 0.3019943
# 6  Nora Preis           Central Asia   188206.64   56321.395 0.2992530
# 7  Giulietta Dortch     Caribbean       81070.22   24036.372 0.2964883
# 8  Chuck Magee          South          400226.76  117787.467 0.2943018
# 9  Jack Lebron          North          312041.40   88914.168 0.2849435
# 10 Matt Collister       West           181364.46   50544.938 0.2786926
# 11 Anna Andreadi        Central        705575.63  186168.595 0.2638535
# 12 Shirley Daniels      North Asia     212077.45   49137.293 0.2316950
# 13 Kelly Williams       East           169695.31   35936.330 0.2117697

# %% [markdown]
# ### Q4. Are underperforming regions associated with specific managers or structural factors?

# %%
region_sales <- orders_with_managers %>%
    group_by(region, person) %>%
    summarise(
        total_sales = sum(sales),
        .groups = "drop"
    )

sales_threshold <- quantile(region_sales$total_sales, 0.25)

underperforming_regions <- region_sales %>%
    filter(total_sales <= sales_threshold)

underperforming_regions
# Out:
#   region    person           total_sales
# 1 Canada    Nicole Hansen     66928.17
# 2 Caribbean Giulietta Dortch 324280.86
# 3 East      Kelly Williams   678781.24
# 4 West      Matt Collister   725457.82

# %%
underperforming_diagnostics <- orders_with_managers %>%
    filter(region %in% underperforming_regions$region) %>%
    group_by(region, person) %>%
    summarise(
        avg_discount = mean(discount, na.rm = TRUE),
        avg_shipping_cost = mean(shipping_cost, na.rm = TRUE),
        avg_profit_margin = sum(profit, na.rm = TRUE) / sum(sales, na.rm = TRUE),
        .groups = "drop"
    )

underperforming_diagnostics
# Out:
#   region    person           avg_discount avg_shipping_cost avg_profit_margin
# 1 Canada    Nicole Hansen    0.0000000    19.28549          0.2662166
# 2 Caribbean Giulietta Dortch 0.1357515    21.05880          0.1066092
# 3 East      Kelly Williams   0.1453652    25.54200          0.1348340
# 4 West      Matt Collister   0.1093350    23.88769          0.1494483

# %% [markdown]
# # Product & Segment Exposure

# %% [markdown]
# ### Q5. Do managers oversee regions with significantly different product or segment mixes?

# %%
manager_product_mix <- orders_with_managers %>%
    group_by(person, category) %>%
    summarise(
        total_sales = sum(sales, na.rm = TRUE),
        .groups = "drop"
    ) %>%
    group_by(person) %>%
    mutate(
        category_share = total_sales / sum(total_sales)
    )

manager_product_mix
# Out:
#    person               category        total_sales category_share
# 1  Alejandro Ballentine Furniture        313386.70  0.3543402
# 2  Alejandro Ballentine Office Supplies  241285.08  0.2728163
# 3  Alejandro Ballentine Technology       329751.38  0.3728434
# 4  Anna Andreadi        Furniture        860417.58  0.3048637
# 5  Anna Andreadi        Office Supplies  923435.28  0.3271922
# 6  Anna Andreadi        Technology      1038449.66  0.3679441
# 7  Anthony Jacobs       Furniture        410468.00  0.3730901
# 8  Anthony Jacobs       Office Supplies  281713.63  0.2560603
# 9  Anthony Jacobs       Technology       408002.98  0.3708496
# 10 Chuck Magee          Furniture        515749.62  0.3221609
# 11 Chuck Magee          Office Supplies  515161.34  0.3217934
# 12 Chuck Magee          Technology       569996.09  0.3560457
# 13 Deborah Brumfield    Furniture        194650.64  0.2483507
# 14 Deborah Brumfield    Office Supplies  266755.53  0.3403479
# 15 Deborah Brumfield    Technology       322367.04  0.4113014
# 16 Giulietta Dortch     Furniture        118372.40  0.3650305
# 17 Giulietta Dortch     Office Supplies   89575.42  0.2762279
# 18 Giulietta Dortch     Technology       116333.05  0.3587416
# 19 Jack Lebron          Furniture        377629.92  0.3025479
# 20 Jack Lebron          Office Supplies  374733.45  0.3002274
# 21 Jack Lebron          Technology       495802.23  0.3972247
# 22 Kelly Williams       Furniture        208291.20  0.3068606
# 23 Kelly Williams       Office Supplies  205516.05  0.3027721
# 24 Kelly Williams       Technology       264973.98  0.3903673
# 25 Matt Collister       Furniture        252612.74  0.3482115
# 26 Matt Collister       Office Supplies  220853.25  0.3044329
# 27 Matt Collister       Technology       251991.83  0.3473556
# 28 Nicole Hansen        Furniture         10595.28  0.1583082
# 29 Nicole Hansen        Office Supplies   30034.08  0.4487510
# 30 Nicole Hansen        Technology        26298.81  0.3929408
# 31 Nora Preis           Furniture        284362.90  0.3777270
# 32 Nora Preis           Office Supplies  162766.35  0.2162070
# 33 Nora Preis           Technology       305697.32  0.4060661
# 34 Shirley Daniels      Furniture        335716.46  0.3957475
# 35 Shirley Daniels      Office Supplies  198554.78  0.2340593
# 36 Shirley Daniels      Technology       314038.55  0.3701932
# 37 NA                   Furniture        228620.74  0.2835918
# 38 NA                   Office Supplies  276685.99  0.3432142
# 39 NA                   Technology       300854.58  0.3731940

# %%
manager_segment_mix <- orders_with_managers %>%
    group_by(person, segment) %>%
    summarise(
        total_sales = sum(sales, na.rm = TRUE),
        .groups = "drop"
    ) %>%
    group_by(person) %>%
    mutate(
        segment_share = total_sales / sum(total_sales)
    )

manager_segment_mix
# Out:
#    person               segment     total_sales segment_share
# 1  Alejandro Ballentine Consumer     460752.82  0.5209642
# 2  Alejandro Ballentine Corporate    254351.71  0.2875905
# 3  Alejandro Ballentine Home Office  169318.65  0.1914453
# 4  Anna Andreadi        Consumer    1479981.17  0.5243879
# 5  Anna Andreadi        Corporate    850363.90  0.3013015
# 6  Anna Andreadi        Home Office  491957.45  0.1743107
# 7  Anthony Jacobs       Consumer     579550.47  0.5267757
# 8  Anthony Jacobs       Corporate    322826.91  0.2934298
# 9  Anthony Jacobs       Home Office  197807.23  0.1797946
# 10 Chuck Magee          Consumer     824890.16  0.5152642
# 11 Chuck Magee          Corporate    496014.60  0.3098335
# 12 Chuck Magee          Home Office  280002.28  0.1749023
# 13 Deborah Brumfield    Consumer     423766.81  0.5406753
# 14 Deborah Brumfield    Corporate    204938.95  0.2614774
# 15 Deborah Brumfield    Home Office  155067.45  0.1978473
# 16 Giulietta Dortch     Consumer     162349.21  0.5006438
# 17 Giulietta Dortch     Corporate    104537.86  0.3223683
# 18 Giulietta Dortch     Home Office   57393.80  0.1769879
# 19 Jack Lebron          Consumer     643955.14  0.5159212
# 20 Jack Lebron          Corporate    394226.15  0.3158444
# 21 Jack Lebron          Home Office  209984.31  0.1682343
# 22 Kelly Williams       Consumer     350908.17  0.5169680
# 23 Kelly Williams       Corporate    200409.35  0.2952488
# 24 Kelly Williams       Home Office  127463.73  0.1877832
# 25 Matt Collister       Consumer     362880.77  0.5002093
# 26 Matt Collister       Corporate    225855.27  0.3113279
# 27 Matt Collister       Home Office  136721.78  0.1884628
# 28 Nicole Hansen        Consumer      35719.11  0.5336932
# 29 Nicole Hansen        Corporate     19313.73  0.2885740
# 30 Nicole Hansen        Home Office   11895.33  0.1777328
# 31 Nora Preis           Consumer     369055.49  0.4902264
# 32 Nora Preis           Corporate    235540.37  0.3128747
# 33 Nora Preis           Home Office  148230.71  0.1968989
# 34 Shirley Daniels      Consumer     407394.92  0.4802431
# 35 Shirley Daniels      Corporate    265747.33  0.3132668
# 36 Shirley Daniels      Home Office  175167.53  0.2064901
# 37 NA                   Consumer     406745.18  0.5045457
# 38 NA                   Corporate    250571.39  0.3108204
# 39 NA                   Home Office  148844.73  0.1846339
