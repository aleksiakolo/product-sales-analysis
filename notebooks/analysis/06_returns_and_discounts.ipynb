# %%
# Load required libraries
library(tidyverse)
library(janitor)
library(dplyr)
library(ggplot2)
library(skimr)
library(purrr)
library(lubridate)

# Source helper scripts
source("../../R/apply_factors.R")
source("../../R/analysis_helpers.R")
source("../../R/temporal_helpers.R")

# Load data
tables <- list(
  Orders  = readr::read_csv("../../data/processed/Orders.csv"),
  Returns = readr::read_csv("../../data/processed/Returns.csv"),
  People  = readr::read_csv("../../data/processed/People.csv")
)

# Apply factor transformations
tables <- apply_factors(tables)

# Extract tables
orders  <- tables$Orders
returns <- tables$Returns
people  <- tables$People
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
# Rows: 51290 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): order_id, ship_mode, customer_name, segment, state, country, mark...
# dbl   (6): sales, quantity, discount, profit, shipping_cost, year
# date  (2): order_date, ship_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1173 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): order_id, market
# lgl (1): returned
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): person, region
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # General Return Overview

# %% [markdown]
# ### Q1. What proportion of orders are returned overall?

# %%
total_orders <- orders |>  distinct(order_id) |>  nrow()returned_orders <- returns |>  distinct(order_id) |>  nrow()overall_return_rate <- returned_orders / total_ordersoverall_return_rate
# Out:
# [1] 0.04681446

# %% [markdown]
# ### Q2. How do return rates differ across markets and regions?

# %%
orders_returns <- orders |>  select(order_id, market, region) |>  distinct() |>  left_join(    returns |> distinct(order_id) |> mutate(returned = 1),    by = "order_id"  ) |>  mutate(returned = ifelse(is.na(returned), 0, returned))return_rate_by_region <- orders_returns |>  group_by(market, region) |>  summarise(    orders = n(),    return_rate = mean(returned),    .groups = "drop"  ) |>  arrange(desc(return_rate))return_rate_by_region
# Out:
#    market region         orders return_rate
# 1  APAC   North Asia     1150   0.13826087
# 2  LATAM  North          1329   0.13167795
# 3  US     West           1611   0.11731844
# 4  EU     Central        2576   0.06327640
# 5  EU     South           995   0.06130653
# 6  EU     North          1027   0.05939630
# 7  APAC   Southeast Asia 1517   0.03625577
# 8  LATAM  South          1456   0.03365385
# 9  APAC   Oceania        1744   0.03325688
# 10 LATAM  Central        1504   0.03324468
# 11 US     Central        1175   0.03319149
# 12 US     East           1401   0.03211991
# 13 LATAM  Caribbean       855   0.02923977
# 14 US     South           822   0.02919708
# 15 APAC   Central Asia   1026   0.02339181
# 16 Africa Africa         2232   0.00000000
# 17 Canada Canada          201   0.00000000
# 18 EMEA   EMEA           2462   0.00000000

# %% [markdown]
# # Product & Category Signals

# %% [markdown]
# ### Q3. Which product categories and sub-categories have the highest/lowest return rates?

# %%
return_rate_by_category <- orders |>  select(order_id, category, sub_category) |>  distinct() |>  left_join(    returns |> distinct(order_id) |> mutate(returned = 1),    by = "order_id"  ) |>  mutate(returned = ifelse(is.na(returned), 0, returned)) |>  group_by(category, sub_category) |>  summarise(    orders = n(),    return_rate = mean(returned),    .groups = "drop"  ) |>  arrange(desc(return_rate))return_rate_by_category
# Out:
#    category        sub_category orders return_rate
# 1  Furniture       Tables        836   0.07535885
# 2  Office Supplies Fasteners    2304   0.07204861
# 3  Office Supplies Appliances   1686   0.07176750
# 4  Technology      Accessories  2889   0.06957425
# 5  Office Supplies Paper        3234   0.06555349
# 6  Furniture       Furnishings  2965   0.06441821
# 7  Furniture       Chairs       3187   0.06087229
# 8  Office Supplies Envelopes    2310   0.06017316
# 9  Technology      Copiers      2120   0.05943396
# 10 Office Supplies Supplies     2281   0.05918457
# 11 Furniture       Bookcases    2284   0.05910683
# 12 Technology      Phones       3133   0.05872965
# 13 Office Supplies Binders      5392   0.05415430
# 14 Office Supplies Labels       2460   0.05406504
# 15 Technology      Machines     1422   0.04852321
# 16 Office Supplies Storage      4534   0.04852228
# 17 Office Supplies Art          4366   0.04489235

# %% [markdown]
# ### Q4. Are high-return products also high-sales products?

# %%
product_returns_sales <- orders |>  group_by(product_id, product_name) |>  summarise(    total_sales = sum(sales),    orders = n_distinct(order_id),    .groups = "drop"  ) |>  left_join(    orders |>      select(order_id, product_id) |>      distinct() |>      left_join(        returns |> distinct(order_id) |> mutate(returned = 1),        by = "order_id"      ) |>      mutate(returned = ifelse(is.na(returned), 0, returned)) |>      group_by(product_id) |>      summarise(return_rate = mean(returned), .groups = "drop"),    by = "product_id"  )product_returns_sales |> arrange(desc(return_rate))
# Out:
#       product_id
# 1     FUR-BO-10000214
# 2     FUR-BO-10002206
# 3     FUR-CH-10000042
# 4     FUR-FU-10002614
# 5     FUR-TA-10000022
# 6     FUR-TA-10000519
# 7     FUR-TA-10000591
# 8     FUR-TA-10000670
# 9     FUR-TA-10000945
# 10    FUR-TA-10001327
# 11    FUR-TA-10001693
# 12    FUR-TA-10002611
# 13    FUR-TA-10002638
# 14    FUR-TA-10003185
# 15    FUR-TA-10003785
# 16    FUR-TA-10004584
# 17    FUR-TA-10004810
# 18    OFF-AP-10000003
# 19    OFF-AP-10000162
# 20    OFF-AP-10000344
# 21    OFF-AP-10000806
# 22    OFF-AP-10001408
# 23    OFF-AP-10001815
# 24    OFF-AP-10002321
# 25    OFF-AP-10004821
# 26    OFF-AR-10001598
# 27    OFF-AR-10003085
# 28    OFF-BI-10000397
# 29    OFF-BI-10000968
# 30    OFF-BI-10003985
# ⋮     ⋮
# 10739 TEC-SHA-10004083
# 10740 TEC-SHA-10004151
# 10741 TEC-SHA-10004184
# 10742 TEC-SHA-10004390
# 10743 TEC-SHA-10004658
# 10744 TEC-SHA-10004874
# 10745 TEC-STA-10000008
# 10746 TEC-STA-10000546
# 10747 TEC-STA-10000699
# 10748 TEC-STA-10000893
# 10749 TEC-STA-10001232
# 10750 TEC-STA-10001407
# 10751 TEC-STA-10001487
# 10752 TEC-STA-10001994
# 10753 TEC-STA-10002286
# 10754 TEC-STA-10002459
# 10755 TEC-STA-10002497
# 10756 TEC-STA-10002650
# 10757 TEC-STA-10003065
# 10758 TEC-STA-10003081
# 10759 TEC-STA-10003330
# 10760 TEC-STA-10003386
# 10761 TEC-STA-10003447
# 10762 TEC-STA-10003550
# 10763 TEC-STA-10003925
# 10764 TEC-STA-10004181
# 10765 TEC-STA-10004536
# 10766 TEC-STA-10004542
# 10767 TEC-STA-10004834
# 10768 TEC-STA-10004927
#       product_name
# 1     Ikea Library with Doors, Pine
# 2     Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, *Special Order
# 3     Harbour Creations Swivel Stool, Black
# 4     Tenex Door Stop, Black
# 5     Hon Conference Table, Adjustable Height
# 6     Bevis Computer Table, Fully Assembled
# 7     Chromcraft Training Table, with Bottom Storage
# 8     Chromcraft Coffee Table, Adjustable Height
# 9     Bevis Coffee Table, Adjustable Height
# 10    Barricks Training Table, Rectangular
# 11    Bevis Training Table, with Bottom Storage
# 12    Barricks Computer Table, with Bottom Storage
# 13    Barricks Wood Table, Rectangular
# 14    Chromcraft Computer Table, Fully Assembled
# 15    Hon Round Table, Adjustable Height
# 16    Hon Training Table, Rectangular
# 17    Barricks Computer Table, Adjustable Height
# 18    KitchenAid Refrigerator, White
# 19    Breville Microwave, Black
# 20    Hoover Toaster, Silver
# 21    KitchenAid Coffee Grinder, Silver
# 22    KitchenAid Refrigerator, White
# 23    Hoover Refrigerator, Black
# 24    Hoover Microwave, Silver
# 25    Hamilton Beach Stove, Black
# 26    BIC Highlighters, Easy-Erase
# 27    Stanley Markers, Easy-Erase
# 28    Wilson Jones Hole Reinforcements, Durable
# 29    Acco Hole Reinforcements, Recycled
# 30    Cardinal Index Tab, Economy
# ⋮     ⋮
# 10739 Sharp Fax and Copier, Laser
# 10740 Sharp Fax and Copier, Color
# 10741 Sharp Personal Copier, High-Speed
# 10742 Sharp Wireless Fax, Digital
# 10743 Sharp Ink, Laser
# 10744 Sharp Fax Machine, High-Speed
# 10745 StarTech Calculator, Wireless
# 10746 StarTech Calculator, Red
# 10747 StarTech Phone, Red
# 10748 StarTech Inkjet, White
# 10749 StarTech Phone, Durable
# 10750 StarTech Phone, Wireless
# 10751 StarTech Calculator, White
# 10752 StarTech Printer, Wireless
# 10753 StarTech Receipt Printer, White
# 10754 StarTech Printer, Durable
# 10755 StarTech Card Printer, White
# 10756 StarTech Card Printer, Wireless
# 10757 StarTech Receipt Printer, Durable
# 10758 StarTech Phone, White
# 10759 StarTech Printer, Red
# 10760 StarTech Inkjet, Wireless
# 10761 StarTech Printer, White
# 10762 StarTech Card Printer, Red
# 10763 StarTech Card Printer, Durable
# 10764 StarTech Inkjet, Durable
# 10765 StarTech Inkjet, Wireless
# 10766 StarTech Calculator, Durable
# 10767 StarTech Receipt Printer, Red
# 10768 StarTech Receipt Printer, Wireless
#       total_sales orders return_rate
# 1      291.7920   1      1
# 2      119.8330   1      1
# 3      355.3800   1      1
# 4      131.6700   1      1
# 5     3694.6800   1      1
# 6      692.3280   1      1
# 7      993.6150   1      1
# 8      538.5600   1      1
# 9      640.7400   1      1
# 10     334.8222   1      1
# 11     267.9840   1      1
# 12    1280.0800   1      1
# 13     545.3700   1      1
# 14     622.8600   1      1
# 15     828.9600   1      1
# 16     132.1080   1      1
# 17    1267.7600   1      1
# 18    1420.4160   1      1
# 19    1355.1300   1      1
# 20     227.8530   1      1
# 21     256.3920   1      1
# 22     420.8640   1      1
# 23    1419.3630   1      1
# 24    1856.3400   1      1
# 25     288.9440   1      1
# 26      51.2000   1      1
# 27      44.9400   1      1
# 28       4.8240   1      1
# 29      14.0400   1      1
# 30      17.5200   1      1
# ⋮     ⋮           ⋮      ⋮
# 10739 1348.800    3      0
# 10740  510.120    2      0
# 10741  508.260    4      0
# 10742 1777.800    4      0
# 10743  124.410    1      0
# 10744 2438.955    5      0
# 10745  631.368    5      0
# 10746  831.264    7      0
# 10747  379.851    5      0
# 10748 1614.168    4      0
# 10749  462.768    6      0
# 10750  447.120    5      0
# 10751  326.145    7      0
# 10752 1537.020    4      0
# 10753 1089.900    3      0
# 10754  307.548    1      0
# 10755 2671.515    6      0
# 10756  735.750    5      0
# 10757   44.280    1      0
# 10758 1320.033    6      0
# 10759 3495.816    7      0
# 10760 3320.790    3      0
# 10761 1883.892    4      0
# 10762 2152.710    6      0
# 10763 1112.616    5      0
# 10764 3121.872    6      0
# 10765 1810.620    5      0
# 10766  897.792    5      0
# 10767  204.687    2      0
# 10768  221.160    1      0

# %% [markdown]
# # Segment & Behavioral Patterns

# %% [markdown]
# ### Q5. Do return rates differ across customer segments?

# %%
return_rate_by_segment <- orders_returns |>  left_join(    orders |> select(order_id, segment) |> distinct(),    by = "order_id",    relationship = "many-to-many"  ) |>  group_by(segment) |>  summarise(    orders = n(),    return_rate = mean(returned),    .groups = "drop"  ) |>  arrange(desc(return_rate))return_rate_by_segment
# Out:
#   segment     orders return_rate
# 1 Corporate    7697  0.04936988
# 2 Consumer    13141  0.04641960
# 3 Home Office  4706  0.04377391

# %% [markdown]
# # Diagnostic Questions

# %% [markdown]
# ### Q6. Are returns concentrated in a small subset of products or regions?

# %%
return_concentration <- orders_returns |>  group_by(region) |>  summarise(    total_returns = sum(returned),    .groups = "drop"  ) |>  arrange(desc(total_returns)) |>  mutate(    cumulative_returns = cumsum(total_returns),    cumulative_share = cumulative_returns / sum(total_returns)  )return_concentration
# Out:
#    region         total_returns cumulative_returns cumulative_share
# 1  Central        252            252               0.2141037
# 2  North          236            488               0.4146134
# 3  West           189            677               0.5751912
# 4  North Asia     159            836               0.7102804
# 5  South          134            970               0.8241291
# 6  Oceania         58           1028               0.8734070
# 7  Southeast Asia  55           1083               0.9201359
# 8  East            45           1128               0.9583687
# 9  Caribbean       25           1153               0.9796092
# 10 Central Asia    24           1177               1.0000000
# 11 Africa           0           1177               1.0000000
# 12 Canada           0           1177               1.0000000
# 13 EMEA             0           1177               1.0000000

# %% [markdown]
# ### Q7. Are high return rates associated with high order volume or low order value?

# %%
returns_volume_value <- orders_returns |>  left_join(    orders |>      group_by(order_id) |>      summarise(        order_sales = sum(sales),        .groups = "drop"      ),    by = "order_id"  )cor(returns_volume_value$returned, returns_volume_value$order_sales, use = "complete.obs")
# Out:
# [1] 0.05297308

# %% [markdown]
# # Discount Behavior

# %% [markdown]
# ### Q8. How do discounts affect profit and order value?

# %%
discount_profit_summary <- orders |>  summarise(    avg_discount = mean(discount),    avg_sales = mean(sales),    avg_profit = mean(profit),    correlation_discount_profit = cor(discount, profit, use = "complete.obs"),    correlation_discount_sales = cor(discount, sales, use = "complete.obs")  )discount_profit_summary
# Out:
#   avg_discount avg_sales avg_profit correlation_discount_profit
# 1 0.1429075    246.4906  28.64174   -0.316375
#   correlation_discount_sales
# 1 -0.08672187

# %%
discount_buckets <- orders |>  mutate(    discount_bucket = cut(      discount,      breaks = c(0, 0.1, 0.25, 0.5, 1),      labels = c("0–10%", "10–25%", "25–50%", "50%+"),      include.lowest = TRUE    )  ) |>  group_by(discount_bucket) |>  summarise(    avg_sales = mean(sales),    avg_profit = mean(profit),    profit_margin = sum(profit) / sum(sales),    n_orders = n(),    .groups = "drop"  )discount_buckets
# Out:
#   discount_bucket avg_sales avg_profit profit_margin n_orders
# 1 0–10%           265.8225   62.64729   0.23567337   33688
# 2 10–25%          285.8180   26.63291   0.09318138    6513
# 3 25–50%          210.2523  -58.16188  -0.27662900    6917
# 4 50%+             89.0759  -98.89301  -1.11021065    4172

# %% [markdown]
# ### Q9. Are discounts applied differently across segments or regions?

# %%
discount_by_segment <- orders |>  group_by(segment) |>  summarise(    avg_discount = mean(discount),    share_discounted_orders = mean(discount > 0),    .groups = "drop"  )discount_by_segment
# Out:
#   segment     avg_discount share_discounted_orders
# 1 Consumer    0.1436022    0.4374010
# 2 Corporate   0.1429311    0.4359971
# 3 Home Office 0.1408971    0.4233116

# %%
discount_by_region <- orders |>  group_by(region) |>  summarise(    avg_discount = mean(discount),    share_discounted_orders = mean(discount > 0),    .groups = "drop"  )discount_by_region
# Out:
#    region         avg_discount share_discounted_orders
# 1  Africa         0.15670373   0.2302158
# 2  Canada         0.00000000   0.0000000
# 3  Caribbean      0.13575148   0.5426036
# 4  Central        0.13885131   0.4643339
# 5  Central Asia   0.06748047   0.1484375
# 6  East           0.14536517   0.4912219
# 7  EMEA           0.19608272   0.3199443
# 8  North          0.09605643   0.3366771
# 9  North Asia     0.04871685   0.1107784
# 10 Oceania        0.15316891   0.8557499
# 11 South          0.14905011   0.4102333
# 12 Southeast Asia 0.27207734   0.8843081
# 13 West           0.10933500   0.4642523

# %% [markdown]
# ### Q10. Which times/products have the most discounts?

# %%
discount_by_product <- orders |>  group_by(product_name) |>  summarise(    avg_discount = mean(discount, na.rm = TRUE),    max_discount = max(discount, na.rm = TRUE),    share_discounted_orders = mean(discount > 0),    n_orders = n(),    .groups = "drop"  ) |>  arrange(desc(avg_discount))discount_by_product |> slice_head(n = 20)
# Out:
#    product_name
# 1  Chromcraft Training Table, Adjustable Height
# 2  Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac
# 3  GBC Plasticlear Binding Covers
# 4  GBC VeloBinder Electric Binding Machine
# 5  Brother MFC-9340CDW LED All-In-One Printer, Copier Scanner
# 6  Bush Westfield Collection Bookcases, Dark Cherry Finish, Fully Assembled
# 7  Cisco 8961 IP Phone Charcoal
# 8  Epson Perfection V600 Photo Scanner
# 9  Hewlett-Packard Deskjet F4180 All-in-One Color Ink-jet - Printer / copier / scanner
# 10 Lexmark MarkNet N8150 Wireless Print Server
# 11 Okidata B401 Printer
# 12 Plantronics Single Ear Headset
# 13 Zebra GK420t Direct Thermal/Thermal Transfer Printer
# 14 Premier Elliptical Ring Binder, Black
# 15 Wilson Jones Custom Binder Spines & Labels
# 16 Acco D-Ring Binder w/DublLock
# 17 Avery Durable Slant Ring Binders
# 18 Avery Triangle Shaped Sheet Lifters, Black, 2/Pack
# 19 Avery Hidden Tab Dividers for Binding Systems
# 20 Euro Pro Shark Stick Mini Vacuum
#    avg_discount max_discount share_discounted_orders n_orders
# 1  0.8000000    0.8          1.0000000               1
# 2  0.8000000    0.8          1.0000000               1
# 3  0.7285714    0.8          1.0000000               7
# 4  0.7250000    0.8          1.0000000               4
# 5  0.7000000    0.7          1.0000000               1
# 6  0.7000000    0.7          1.0000000               1
# 7  0.7000000    0.7          1.0000000               1
# 8  0.7000000    0.7          1.0000000               1
# 9  0.7000000    0.7          1.0000000               1
# 10 0.7000000    0.7          1.0000000               2
# 11 0.7000000    0.7          1.0000000               1
# 12 0.7000000    0.7          1.0000000               1
# 13 0.7000000    0.7          1.0000000               1
# 14 0.6444444    0.8          0.8888889               9
# 15 0.6285714    0.7          1.0000000               7
# 16 0.6222222    0.8          1.0000000               9
# 17 0.6200000    0.8          1.0000000               5
# 18 0.6166667    0.8          0.8333333               6
# 19 0.6142857    0.8          1.0000000               7
# 20 0.6000000    0.8          1.0000000               3

# %%
discount_over_time <- orders |>  add_time_period("order_date", period = "month") |>  group_by(period) |>  summarise(    avg_discount = mean(discount),    share_discounted_orders = mean(discount > 0),    .groups = "drop"  ) |>  arrange(desc(avg_discount))discount_over_time
# Out:
#    period     avg_discount share_discounted_orders
# 1  2011-06-01 0.1739738    0.4961832
# 2  2011-07-01 0.1617899    0.5010101
# 3  2011-01-01 0.1587945    0.4087760
# 4  2012-07-01 0.1584279    0.4962064
# 5  2011-11-01 0.1570114    0.4512730
# 6  2014-04-01 0.1560419    0.4643197
# 7  2014-12-01 0.1556461    0.4509986
# 8  2012-03-01 0.1535982    0.4501511
# 9  2014-07-01 0.1504250    0.4241030
# 10 2013-03-01 0.1493264    0.4451697
# 11 2011-12-01 0.1482344    0.4687253
# 12 2012-06-01 0.1481373    0.4480634
# 13 2013-04-01 0.1479185    0.4394904
# 14 2012-11-01 0.1478548    0.4335616
# 15 2014-05-01 0.1471854    0.4338006
# 16 2014-02-01 0.1469921    0.4669312
# 17 2012-02-01 0.1463497    0.4289044
# 18 2013-10-01 0.1462364    0.4463636
# 19 2011-05-01 0.1455512    0.4363958
# 20 2013-05-01 0.1448363    0.4664144
# 21 2014-06-01 0.1438570    0.4336384
# 22 2014-10-01 0.1437589    0.4464945
# 23 2011-04-01 0.1432305    0.4060284
# 24 2013-09-01 0.1430880    0.4405470
# 25 2011-10-01 0.1423669    0.4573643
# 26 2012-04-01 0.1419300    0.4611872
# 27 2014-11-01 0.1417718    0.4527247
# 28 2013-08-01 0.1405270    0.4133148
# 29 2013-06-01 0.1396353    0.4117647
# 30 2013-12-01 0.1396330    0.4107366
# 31 2014-01-01 0.1393551    0.4117647
# 32 2011-08-01 0.1383394    0.4031891
# 33 2012-09-01 0.1382420    0.4178250
# 34 2011-02-01 0.1382328    0.3703704
# 35 2012-01-01 0.1381336    0.3784787
# 36 2011-03-01 0.1376846    0.4582560
# 37 2012-10-01 0.1372384    0.4323232
# 38 2012-05-01 0.1360381    0.4345238
# 39 2013-07-01 0.1358314    0.4172973
# 40 2013-11-01 0.1349148    0.4317043
# 41 2014-09-01 0.1348335    0.4137760
# 42 2012-12-01 0.1344829    0.4322430
# 43 2014-03-01 0.1329738    0.4082397
# 44 2011-09-01 0.1308726    0.4192015
# 45 2014-08-01 0.1299534    0.4137313
# 46 2013-01-01 0.1289732    0.4146685
# 47 2013-02-01 0.1289455    0.3867769
# 48 2012-08-01 0.1257304    0.4062789
