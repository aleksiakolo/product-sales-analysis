# %%
# Load required libraries
library(tidyverse)
library(janitor)
library(dplyr)
library(ggplot2)
library(skimr)
library(purrr)
library(lubridate)

# Source helper scripts
source("../../R/apply_factors.R")
source("../../R/analysis_helpers.R")
source("../../R/temporal_helpers.R")

# Load data
tables <- list(
  Orders  = readr::read_csv("../../data/processed/Orders.csv"),
  Returns = readr::read_csv("../../data/processed/Returns.csv"),
  People  = readr::read_csv("../../data/processed/People.csv")
)

# Apply factor transformations
tables <- apply_factors(tables)

# Extract tables
orders  <- tables$Orders
returns <- tables$Returns
people  <- tables$People
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
# Rows: 51290 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): order_id, ship_mode, customer_name, segment, state, country, mark...
# dbl   (6): sales, quantity, discount, profit, shipping_cost, year
# date  (2): order_date, ship_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1173 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): order_id, market
# lgl (1): returned
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): person, region
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # General Product Performance

# %% [markdown]
# ### Which products generate the highest/lowest total sales?

# %%
product_sales <- orders |>  
    group_by(product_name, category, sub_category) |>  
    summarize(    
        total_sales = sum(sales),
        n_orders = n()  
        ) |>  
        ungroup() |>  
        arrange(desc(total_sales))

product_sales |> slice_head(n = 10)
# Out:
# `summarise()` has grouped output by 'product_name', 'category'. You can
# override using the `.groups` argument.
#    product_name                                             category
# 1  Apple Smart Phone, Full Size                             Technology
# 2  Cisco Smart Phone, Full Size                             Technology
# 3  Motorola Smart Phone, Full Size                          Technology
# 4  Nokia Smart Phone, Full Size                             Technology
# 5  Canon imageCLASS 2200 Advanced Copier                    Technology
# 6  Hon Executive Leather Armchair, Adjustable               Furniture
# 7  Office Star Executive Leather Armchair, Adjustable       Furniture
# 8  Harbour Creations Executive Leather Armchair, Adjustable Furniture
# 9  Samsung Smart Phone, Cordless                            Technology
# 10 Nokia Smart Phone, with Caller ID                        Technology
#    sub_category total_sales n_orders
# 1  Phones       86935.78    51
# 2  Phones       76441.53    38
# 3  Phones       73156.30    38
# 4  Phones       71904.56    47
# 5  Copiers      61599.82     5
# 6  Chairs       58193.48    49
# 7  Chairs       50661.68    45
# 8  Chairs       50121.52    39
# 9  Phones       48653.46    26
# 10 Phones       47877.79    24

# %%
product_sales |> slice_tail(n = 10)
# Out:
#    product_name
# 1  Newell 308
# 2  Stockwell Gold Paper Clips
# 3  4009 Highlighters
# 4  Xerox 1989
# 5  Avery Hi-Liter Comfort Grip Fluorescent Highlighter, Yellow Ink
# 6  Avery Hi-Liter Pen Style Six-Color Fluorescent Set
# 7  Grip Seal Envelopes
# 8  Xerox 20
# 9  Avery 5
# 10 Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac
#    category        sub_category total_sales n_orders
# 1  Office Supplies Art          8.400       2
# 2  Office Supplies Fasteners    8.096       2
# 3  Office Supplies Art          8.040       1
# 4  Office Supplies Paper        7.968       1
# 5  Office Supplies Art          7.800       2
# 6  Office Supplies Art          7.700       1
# 7  Office Supplies Envelopes    7.072       1
# 8  Office Supplies Paper        6.480       1
# 9  Office Supplies Labels       5.760       1
# 10 Office Supplies Appliances   1.624       1

# %% [markdown]
# ### Which product categories perform best/worst?

# %%
category_sales <- orders |>  
    group_by(category) |>  
    summarize(    
        total_sales = sum(sales),    
        n_orders = n()  
        ) |>  
        arrange(desc(total_sales))

category_sales
# Out:
#   category        total_sales n_orders
# 1 Technology      4744557     10141
# 2 Furniture       4110874      9876
# 3 Office Supplies 3787070     31273

# %% [markdown]
# ### Which product sub-categories perform best/worst?

# %%
subcategory_sales <- orders |>
    group_by(category, sub_category) |>
    summarize(    
        total_sales = sum(sales),    
        n_orders = n()  
    ) |>  
    arrange(desc(total_sales))
subcategory_sales
# Out:
# `summarise()` has grouped output by 'category'. You can override using the
# `.groups` argument.
#    category        sub_category total_sales n_orders
# 1  Technology      Phones       1706824.14  3357
# 2  Technology      Copiers      1509436.27  2223
# 3  Furniture       Chairs       1501681.76  3434
# 4  Furniture       Bookcases    1466572.24  2411
# 5  Office Supplies Storage      1127085.86  5059
# 6  Office Supplies Appliances   1011064.30  1755
# 7  Technology      Machines      779060.07  1486
# 8  Furniture       Tables        757041.92   861
# 9  Technology      Accessories   749237.02  3075
# 10 Office Supplies Binders       461911.51  6152
# 11 Furniture       Furnishings   385578.26  3170
# 12 Office Supplies Art           372091.97  4883
# 13 Office Supplies Paper         244291.72  3538
# 14 Office Supplies Supplies      243074.22  2425
# 15 Office Supplies Envelopes     170904.30  2435
# 16 Office Supplies Fasteners      83242.32  2420
# 17 Office Supplies Labels         73404.03  2606

# %% [markdown]
# # Revenue Structure & Concentration

# %% [markdown]
# ### How concentrated are sales among top products/sub-categories?

# %%
product_sales <- product_sales |>  arrange(desc(total_sales)) |>  
    mutate(    
        cumulative_sales = cumsum(total_sales),    
        cumulative_share = cumulative_sales / sum(total_sales),    
        product_rank = row_number(),    
        product_share = product_rank / n()  
        )

product_sales |>  
    select(product_rank, product_name, total_sales, cumulative_share, product_share) |>
    slice_head(n = 20)
# Out:
#    product_rank product_name
# 1   1           Apple Smart Phone, Full Size
# 2   2           Cisco Smart Phone, Full Size
# 3   3           Motorola Smart Phone, Full Size
# 4   4           Nokia Smart Phone, Full Size
# 5   5           Canon imageCLASS 2200 Advanced Copier
# 6   6           Hon Executive Leather Armchair, Adjustable
# 7   7           Office Star Executive Leather Armchair, Adjustable
# 8   8           Harbour Creations Executive Leather Armchair, Adjustable
# 9   9           Samsung Smart Phone, Cordless
# 10 10           Nokia Smart Phone, with Caller ID
# 11 11           Samsung Smart Phone, VoIP
# 12 12           Cisco Smart Phone, with Caller ID
# 13 13           SAFCO Executive Leather Armchair, Black
# 14 14           Cisco Smart Phone, Cordless
# 15 15           Novimex Executive Leather Armchair, Adjustable
# 16 16           Sauder Classic Bookcase, Traditional
# 17 17           Motorola Smart Phone, Cordless
# 18 18           Novimex Executive Leather Armchair, Red
# 19 19           Eldon File Cart, Single Width
# 20 20           Hoover Stove, White
#    total_sales cumulative_share product_share
# 1  86935.78    0.006876469      0.0002633658
# 2  76441.53    0.012922862      0.0005267316
# 3  73156.30    0.018709399      0.0007900974
# 4  71904.56    0.024396925      0.0010534633
# 5  61599.82    0.029269364      0.0013168291
# 6  58193.48    0.033872368      0.0015801949
# 7  50661.68    0.037879619      0.0018435607
# 8  50121.52    0.041844144      0.0021069265
# 9  48653.46    0.045692549      0.0023702923
# 10 47877.79    0.049479599      0.0026336582
# 11 45406.33    0.053071161      0.0028970240
# 12 43127.50    0.056482471      0.0031603898
# 13 41923.53    0.059798550      0.0034237556
# 14 41021.52    0.063043281      0.0036871214
# 15 40585.13    0.066253495      0.0039504872
# 16 39108.30    0.069346894      0.0042138530
# 17 38931.04    0.072426272      0.0044772189
# 18 38814.80    0.075496456      0.0047405847
# 19 34387.73    0.078216465      0.0050039505
# 20 32842.60    0.080814259      0.0052673163

# %%
subcategory_sales <- subcategory_sales |> 
    ungroup() |>
    arrange(desc(total_sales)) |>  
    mutate(    
        cumulative_sales = cumsum(total_sales), 
        cumulative_share = cumulative_sales / sum(total_sales),    
        subcategory_rank = row_number(),    
        subcategory_share = subcategory_rank / n()  
    )
    
subcategory_sales |> select(subcategory_rank, sub_category, total_sales, cumulative_share, subcategory_share)
# Out:
#    subcategory_rank sub_category total_sales cumulative_share subcategory_share
# 1   1               Phones       1706824.14  0.1350068        0.05882353
# 2   2               Copiers      1509436.27  0.2544006        0.11764706
# 3   3               Chairs       1501681.76  0.3731811        0.17647059
# 4   4               Bookcases    1466572.24  0.4891844        0.23529412
# 5   5               Storage      1127085.86  0.5783349        0.29411765
# 6   6               Appliances   1011064.30  0.6583084        0.35294118
# 7   7               Machines      779060.07  0.7199307        0.41176471
# 8   8               Tables        757041.92  0.7798114        0.47058824
# 9   9               Accessories   749237.02  0.8390747        0.52941176
# 10 10               Binders       461911.51  0.8756111        0.58823529
# 11 11               Furnishings   385578.26  0.9061097        0.64705882
# 12 12               Art           372091.97  0.9355415        0.70588235
# 13 13               Paper         244291.72  0.9548646        0.76470588
# 14 14               Supplies      243074.22  0.9740913        0.82352941
# 15 15               Envelopes     170904.30  0.9876095        0.88235294
# 16 16               Fasteners      83242.32  0.9941939        0.94117647
# 17 17               Labels         73404.03  1.0000000        1.00000000

# %% [markdown]
# ### What share of products generate little or no revenue?

# %%
low_share <- 0.005

low_revenue_share_summary <- product_sales |>  
    arrange(total_sales) |>  
    mutate(    
        total_sales_all = sum(total_sales),    
        cum_sales = cumsum(total_sales),    
        cum_share = cum_sales / total_sales_all  
    ) |>  
    summarise(    
        total_products = n(),    
        low_revenue_products = sum(cum_share <= low_share),    
        share_products = low_revenue_products / total_products  
    )

low_revenue_share_summary
# Out:
#   total_products low_revenue_products share_products
# 1 3797           735                  0.1935739

# %%
bottom_share <- 0.10

bottom_products_summary <- product_sales |>  
    arrange(total_sales) |>  
    mutate(    
        total_revenue = sum(total_sales),    
        cum_revenue = cumsum(total_sales),    
        cum_share = cum_revenue / total_revenue  
    ) |>  
    summarise(    
        total_products = n(),    
        products_for_10pct_revenue = sum(cum_share <= bottom_share),    
        share_of_products = products_for_10pct_revenue / total_products  
    )

bottom_products_summary
# Out:
#   total_products products_for_10pct_revenue share_of_products
# 1 3797           2209                       0.5817751

# %% [markdown]
# # Volume vs Value

# %% [markdown]
# ### Are top-selling products high-volume or high-value?

# %%
product_volume_value <- orders |>  
    group_by(product_name) |>  
    summarise(    
        total_sales = sum(sales),    
        total_quantity = sum(quantity),    
        avg_price_per_unit = total_sales / total_quantity,    
        n_orders = n(),    
        .groups = "drop"  
    )

top_products <- product_volume_value |>  
    arrange(desc(total_sales)) |>  
    slice_head(n = 20)

top_products
# Out:
#    product_name                                             total_sales
# 1  Apple Smart Phone, Full Size                             86935.78
# 2  Cisco Smart Phone, Full Size                             76441.53
# 3  Motorola Smart Phone, Full Size                          73156.30
# 4  Nokia Smart Phone, Full Size                             71904.56
# 5  Canon imageCLASS 2200 Advanced Copier                    61599.82
# 6  Hon Executive Leather Armchair, Adjustable               58193.48
# 7  Office Star Executive Leather Armchair, Adjustable       50661.68
# 8  Harbour Creations Executive Leather Armchair, Adjustable 50121.52
# 9  Samsung Smart Phone, Cordless                            48653.46
# 10 Nokia Smart Phone, with Caller ID                        47877.79
# 11 Samsung Smart Phone, VoIP                                45406.33
# 12 Cisco Smart Phone, with Caller ID                        43127.50
# 13 SAFCO Executive Leather Armchair, Black                  41923.53
# 14 Cisco Smart Phone, Cordless                              41021.52
# 15 Novimex Executive Leather Armchair, Adjustable           40585.13
# 16 Sauder Classic Bookcase, Traditional                     39108.30
# 17 Motorola Smart Phone, Cordless                           38931.04
# 18 Novimex Executive Leather Armchair, Red                  38814.80
# 19 Eldon File Cart, Single Width                            34387.73
# 20 Hoover Stove, White                                      32842.60
#    total_quantity avg_price_per_unit n_orders
# 1  171             508.3964          51
# 2  139             549.9391          38
# 3  134             545.9426          38
# 4  147             489.1466          47
# 5   20            3079.9912           5
# 6  169             344.3401          49
# 7  141             359.3027          45
# 8  142             352.9684          39
# 9  108             450.4950          26
# 10  96             498.7269          24
# 11  97             468.1065          23
# 12  85             507.3824          27
# 13 111             377.6895          28
# 14  89             460.9160          27
# 15 124             327.2995          39
# 16 113             346.0912          29
# 17  74             526.0952          23
# 18 118             328.9390          28
# 19 321             107.1269          90
# 20  81             405.4643          18

# %% [markdown]
# ### Which products have high order frequency but low total sales?

# %%
frequency_threshold <- quantile(product_volume_value$n_orders, 0.75)sales_threshold <- quantile(product_volume_value$total_sales, 0.25)high_freq_low_sales <- product_volume_value |>  filter(    n_orders >= frequency_threshold,    total_sales <= sales_threshold  ) |>  arrange(desc(n_orders))high_freq_low_sales
# Out:
#   product_name                       total_sales total_quantity
# 1 Novimex Round Labels, Adjustable   210.9464    67
# 2 Avery Non-Stick Binders            217.3160    71
# 3 Avery Round Labels, Adjustable     258.0144    65
# 4 Hon Round Labels, Adjustable       250.7088    68
# 5 Novimex Round Labels, Alphabetical 250.5020    63
#   avg_price_per_unit n_orders
# 1 3.148454           22
# 2 3.060789           20
# 3 3.969452           20
# 4 3.686894           20
# 5 3.976222           19

# %% [markdown]
# # Category Structure

# %% [markdown]
# ### How diverse is revenue within each category?

# %%
frequency_threshold <- quantile(product_volume_value$n_orders, 0.75)

sales_threshold <- quantile(product_volume_value$total_sales, 0.25)

high_freq_low_sales <- product_volume_value |>  
    filter(    
        n_orders >= frequency_threshold,    
        total_sales <= sales_threshold  
    ) |>  
    arrange(desc(n_orders))

high_freq_low_sales
# Out:
#   product_name                       total_sales total_quantity
# 1 Novimex Round Labels, Adjustable   210.9464    67
# 2 Avery Non-Stick Binders            217.3160    71
# 3 Avery Round Labels, Adjustable     258.0144    65
# 4 Hon Round Labels, Adjustable       250.7088    68
# 5 Novimex Round Labels, Alphabetical 250.5020    63
#   avg_price_per_unit n_orders
# 1 3.148454           22
# 2 3.060789           20
# 3 3.969452           20
# 4 3.686894           20
# 5 3.976222           19

# %% [markdown]
# ### Are sub-categories performing consistently within categories?

# %%
subcategory_sales <- orders |>  
    group_by(category, sub_category) |>  
    summarise(    
        total_sales = sum(sales),    
        n_products = n_distinct(product_name),    
        .groups = "drop"  
    )

subcategory_consistency <- subcategory_sales |>  
    group_by(category) |>  
    summarise(    
        n_subcategories = n(),    
        mean_sales = mean(total_sales),    
        sd_sales = sd(total_sales),    
        cv_sales = sd_sales / mean_sales,    
        max_to_min_ratio = max(total_sales) / min(total_sales),    
        .groups = "drop"  
    ) |>  
    arrange(desc(cv_sales))

subcategory_consistency
# Out:
#   category        n_subcategories mean_sales sd_sales cv_sales
# 1 Office Supplies 9                420785.6  389090.8 0.9246770
# 2 Furniture       4               1027718.5  548587.2 0.5337913
# 3 Technology      4               1186139.4  494041.4 0.4165121
#   max_to_min_ratio
# 1 15.354550
# 2  3.894623
# 3  2.278083

# %% [markdown]
# # Stability & Consistency

# %% [markdown]
# ### Are top products consistently strong across regions?

# %%
top_products <- product_sales |>  
    arrange(desc(total_sales)) |>  
    slice_head(n = 20) |>  
    pull(product_name)

product_region_sales <- orders |>  
    filter(product_name %in% top_products) |>  
    group_by(product_name, region) |>  
    summarise(    
        regional_sales = sum(sales),    
        .groups = "drop"  
    )

product_region_consistency <- product_region_sales |>  
    group_by(product_name) |>  
    summarise(    
        n_regions = n(),    
        mean_sales = mean(regional_sales),    
        sd_sales = sd(regional_sales),    
        cv_sales = sd_sales / mean_sales,    
        max_to_min_ratio = max(regional_sales) / min(regional_sales),    
        .groups = "drop"  
    ) |>  
    arrange(cv_sales)

product_region_consistency
# Out:
#    product_name                                             n_regions
# 1  Canon imageCLASS 2200 Advanced Copier                     3
# 2  Harbour Creations Executive Leather Armchair, Adjustable  9
# 3  Motorola Smart Phone, Cordless                            9
# 4  Hoover Stove, White                                       9
# 5  Cisco Smart Phone, Full Size                             10
# 6  Apple Smart Phone, Full Size                             10
# 7  Sauder Classic Bookcase, Traditional                     10
# 8  Eldon File Cart, Single Width                             9
# 9  Motorola Smart Phone, Full Size                          11
# 10 Cisco Smart Phone, Cordless                               7
# 11 Samsung Smart Phone, Cordless                             9
# 12 Hon Executive Leather Armchair, Adjustable               11
# 13 Office Star Executive Leather Armchair, Adjustable       10
# 14 Samsung Smart Phone, VoIP                                 9
# 15 Nokia Smart Phone, with Caller ID                         9
# 16 Novimex Executive Leather Armchair, Adjustable            9
# 17 SAFCO Executive Leather Armchair, Black                  10
# 18 Novimex Executive Leather Armchair, Red                  10
# 19 Cisco Smart Phone, with Caller ID                        11
# 20 Nokia Smart Phone, Full Size                             10
#    mean_sales sd_sales cv_sales  max_to_min_ratio
# 1  20533.275  8467.758 0.4123920  2.150000
# 2   5569.057  2455.356 0.4408925  4.032839
# 3   4325.671  2208.118 0.5104682  9.833333
# 4   3649.178  1962.395 0.5377635  5.666667
# 5   7644.153  4162.284 0.5445055  9.440052
# 6   8693.578  4766.375 0.5482639  5.701215
# 7   3910.830  2451.227 0.6267793 13.846154
# 8   3820.859  2420.586 0.6335189 33.369358
# 9   6650.573  4358.910 0.6554187 18.215084
# 10  5860.218  4034.921 0.6885274  8.883333
# 11  5405.940  3865.715 0.7150866 19.950000
# 12  5290.317  4368.781 0.8258071 33.174760
# 13  5066.168  4304.120 0.8495810 21.088584
# 14  5045.148  4433.987 0.8788617 23.333333
# 15  5319.754  4892.750 0.9197324 17.571429
# 16  4509.459  4156.761 0.9217871  9.332713
# 17  4192.353  4368.227 1.0419512 33.500000
# 18  3881.480  4435.368 1.1427000 61.625000
# 19  3920.682  4491.948 1.1457059 82.888889
# 20  7190.456  8305.204 1.1550316 27.406886

# %% [markdown]
# ### Do products perform consistently across customer segments?

# %%
product_segment_sales <- orders |>  
    filter(product_name %in% top_products) |>  
    group_by(product_name, segment) |>  
    summarise(    
        segment_sales = sum(sales),    
        .groups = "drop"  
    )

product_segment_consistency <- product_segment_sales |>  
    group_by(product_name) |>  
    summarise(    
        n_segments = n(),    
        mean_sales = mean(segment_sales),    
        sd_sales = sd(segment_sales),    
        cv_sales = sd_sales / mean_sales,    
        max_to_min_ratio = max(segment_sales) / min(segment_sales),    
        .groups = "drop"  
    ) |>  
    arrange(cv_sales)

product_segment_consistency
# Out:
#    product_name                                             n_segments
# 1  Sauder Classic Bookcase, Traditional                     3
# 2  Apple Smart Phone, Full Size                             3
# 3  Office Star Executive Leather Armchair, Adjustable       3
# 4  Novimex Executive Leather Armchair, Adjustable           3
# 5  Hoover Stove, White                                      3
# 6  Motorola Smart Phone, Full Size                          3
# 7  Motorola Smart Phone, Cordless                           3
# 8  Eldon File Cart, Single Width                            3
# 9  Canon imageCLASS 2200 Advanced Copier                    3
# 10 Harbour Creations Executive Leather Armchair, Adjustable 3
# 11 Nokia Smart Phone, with Caller ID                        3
# 12 SAFCO Executive Leather Armchair, Black                  3
# 13 Hon Executive Leather Armchair, Adjustable               3
# 14 Samsung Smart Phone, VoIP                                3
# 15 Cisco Smart Phone, with Caller ID                        3
# 16 Cisco Smart Phone, Cordless                              3
# 17 Novimex Executive Leather Armchair, Red                  3
# 18 Cisco Smart Phone, Full Size                             3
# 19 Nokia Smart Phone, Full Size                             3
# 20 Samsung Smart Phone, Cordless                            3
#    mean_sales sd_sales  cv_sales  max_to_min_ratio
# 1  13036.10    3244.376 0.2488763  1.671254
# 2  28978.59    8941.616 0.3085594  1.754631
# 3  16887.23    5988.987 0.3546460  1.839752
# 4  13528.38    4891.398 0.3615658  2.167203
# 5  10947.53    4140.998 0.3782585  1.977825
# 6  24385.43   10536.642 0.4320875  2.607857
# 7  12977.01    5855.518 0.4512223  2.420000
# 8  11462.58    5198.821 0.4535473  2.245288
# 9  20533.27   11163.450 0.5436761  2.937500
# 10 16707.17    9450.878 0.5656779  3.840565
# 11 15959.26    9871.745 0.6185590  3.108759
# 12 13974.51    9147.575 0.6545900  5.558674
# 13 19397.83   12883.785 0.6641870  3.975897
# 14 15135.44   11309.102 0.7471933  9.600000
# 15 14375.83   10879.327 0.7567789  5.950000
# 16 13673.84   12175.810 0.8904454  4.656934
# 17 12938.27   11708.679 0.9049650  5.400566
# 18 25480.51   24277.814 0.9527994  9.669687
# 19 23968.19   23244.056 0.9697879  6.835261
# 20 16217.82   16580.739 1.0223778 14.759091

# %% [markdown]
# # Underperformance Diagnostics

# %% [markdown]
# ### Are underperforming products concentrated in specific categories/sub-categories?

# %%
sales_threshold <- quantile(product_sales$total_sales, 0.1)

underperforming_products <- product_sales |>  
    filter(total_sales <= sales_threshold)

underperforming_by_category <- orders |>  
    filter(product_name %in% underperforming_products$product_name) |>  
    group_by(category) |>  
    summarise(    
        total_sales = sum(sales),    
        .groups = "drop"  
    )

underperforming_by_category

underperforming_by_subcategory <- orders |>  
    filter(product_name %in% underperforming_products$product_name) |>  
    group_by(category, sub_category) |>  
    summarise(    
        total_sales = sum(sales),    
        .groups = "drop"  
    ) |>  
    arrange(desc(total_sales))

underperforming_by_subcategory
# Out:
#   category        total_sales
# 1 Furniture        1896.550
# 2 Office Supplies 21463.592
# 3 Technology       1298.158
#    category        sub_category total_sales
# 1  Office Supplies Paper        6608.604
# 2  Office Supplies Art          3999.076
# 3  Office Supplies Binders      2773.146
# 4  Office Supplies Envelopes    2491.514
# 5  Furniture       Furnishings  1806.624
# 6  Office Supplies Fasteners    1718.434
# 7  Office Supplies Labels       1536.926
# 8  Office Supplies Appliances    953.172
# 9  Office Supplies Supplies      764.432
# 10 Office Supplies Storage       618.288
# 11 Technology      Accessories   580.708
# 12 Technology      Phones        573.644
# 13 Technology      Machines      143.806
# 14 Furniture       Tables         89.926

# %% [markdown]
# ### Are there products with high sales but unusually high return rates?

# %%
orders_with_returns <- orders |>  
    inner_join(returns, by = "order_id", relationship = "many-to-many") |>  
    select(order_id, product_name, category, sub_category, sales)

product_returns <- orders_with_returns |>  
    group_by(product_name) |>  
    summarise(    
        total_returned_sales = sum(sales),    
        n_returns = n(),    
        .groups = "drop"  
    ) |>  
    arrange(desc(total_returned_sales))

high_sales_threshold <- quantile(product_returns$total_returned_sales, 0.75)

high_return_threshold <- quantile(product_returns$n_returns, 0.75)

high_sales_high_returns <- product_returns |>  
    filter(    
        total_returned_sales >= high_sales_threshold,    
        n_returns >= high_return_threshold  
    ) |>  
    arrange(desc(n_returns))

high_sales_high_returns
# Out:
#     product_name
# 1   Staples
# 2   HP Copy Machine, Color
# 3   Samsung Smart Phone, VoIP
# 4   KitchenAid Refrigerator, White
# 5   Samsung Audio Dock, Cordless
# 6   Nokia Signal Booster, Cordless
# 7   Hon Rocking Chair, Red
# 8   Novimex Steel Folding Chair, Set of Two
# 9   Office Star Steel Folding Chair, Red
# 10  SanDisk Numeric Keypad, Bluetooth
# 11  Acco Binding Machine, Clear
# 12  Boston Pencil Sharpener, Easy-Erase
# 13  Sharp Fax Machine, Digital
# 14  Sauder Floating Shelf Set, Metal
# 15  Eldon Lockers, Blue
# 16  Tenex Lockers, Blue
# 17  SAFCO Rocking Chair, Red
# 18  KI Adjustable-Height Table
# 19  Sauder 3-Shelf Cabinet, Pine
# 20  Wilson Jones Binding Machine, Recycled
# 21  SanDisk Numeric Keypad, USB
# 22  Smead Shelving, Blue
# 23  Eldon Trays, Blue
# 24  Elite Trimmer, Steel
# 25  Smead Trays, Wire Frame
# 26  GlobeWeis Manila Envelope, Set of 50
# 27  Sanford Pencil Sharpener, Easy-Erase
# 28  SAFCO Bag Chairs, Red
# 29  Novimex Bag Chairs, Black
# 30  Cardinal 3-Hole Punch, Economy
# ⋮   ⋮
# 245 Panasonic Inkjet, White
# 246 Konica Card Printer, Red
# 247 Nokia Office Telephone, Full Size
# 248 Lesro Sheffield Collection Coffee Table, End Table, Center Table, Corner Table
# 249 Xerox 1934
# 250 Sauder Corner Shelving, Metal
# 251 Brother Personal Copier, Color
# 252 Office Star Chairmat, Adjustable
# 253 NETGEAR N750 Dual Band Wi-Fi Gigabit Router
# 254 Xerox 1908
# 255 Breville Coffee Grinder, Black
# 256 Ikea Floating Shelf Set, Traditional
# 257 Harbour Creations Bag Chairs, Black
# 258 Samsung Speaker Phone, VoIP
# 259 Barricks Training Table, Rectangular
# 260 Dania Floating Shelf Set, Traditional
# 261 Boston Canvas, Water Color
# 262 Panasonic Phone, Durable
# 263 HP Ink, High-Speed
# 264 Tenex Frame, Erganomic
# 265 Fellowes Trays, Blue
# 266 Dania 3-Shelf Cabinet, Traditional
# 267 Samsung Headset, VoIP
# 268 Hamilton Beach Toaster, Red
# 269 Rubbermaid Photo Frame, Black
# 270 Sauder Camden County Collection Libraries, Planked Cherry Finish
# 271 SanDisk Router, Bluetooth
# 272 Canon Personal Copier, Digital
# 273 Enermax Keyboard, USB
# 274 Novimex Chairmat, Set of Two
#     total_returned_sales n_returns
# 1     684.6100           17
# 2    6980.3586            8
# 3   17220.8960            6
# 4    5765.8368            5
# 5    2613.0720            5
# 6    2536.6345            5
# 7    1369.3330            5
# 8    1161.6000            5
# 9    1135.0641            5
# 10    812.8500            5
# 11    743.0850            5
# 12    679.7250            5
# 13   4275.6023            4
# 14   2961.6972            4
# 15   2434.2930            4
# 16   2333.4345            4
# 17   1533.4770            4
# 18   1401.4740            4
# 19   1142.6040            4
# 20    772.6800            4
# 21    769.0480            4
# 22    657.2930            4
# 23    657.1890            4
# 24    642.7455            4
# 25    640.3400            4
# 26    629.9700            4
# 27    550.8300            4
# 28    547.1360            4
# 29    536.8700            4
# 30    501.1200            4
# ⋮   ⋮                    ⋮
# 245 579.6000             2
# 246 577.2720             2
# 247 575.6400             2
# 248 570.9600             2
# 249 559.8000             2
# 250 557.6880             2
# 251 556.5365             2
# 252 546.4800             2
# 253 540.0000             2
# 254 537.4080             2
# 255 535.2660             2
# 256 533.7320             2
# 257 532.7100             2
# 258 526.2080             2
# 259 524.3442             2
# 260 519.3400             2
# 261 517.6302             2
# 262 509.7600             2
# 263 507.0924             2
# 264 499.5600             2
# 265 499.2930             2
# 266 488.9455             2
# 267 488.6000             2
# 268 483.0840             2
# 269 483.0000             2
# 270 477.1670             2
# 271 476.8110             2
# 272 474.2203             2
# 273 474.1300             2
# 274 468.7200             2

# %% [markdown]
# # Profitability Overview

# %% [markdown]
# ### Which products generate the most/least profit?

# %%
product_profit <- orders |>  
    group_by(product_name) |>  
    summarise(    
        total_profit = sum(profit),    
        total_sales = sum(sales),    
        n_orders = n(),    
        .groups = "drop"  
    ) |>  
    arrange(desc(total_profit))

product_profit |> 
    slice_head(n = 10)

product_profit |> 
    slice_tail(n = 10)
# Out:
#    product_name                                             total_profit
# 1  Canon imageCLASS 2200 Advanced Copier                    25199.928
# 2  Cisco Smart Phone, Full Size                             17238.521
# 3  Motorola Smart Phone, Full Size                          17027.113
# 4  Hoover Stove, Red                                        11807.969
# 5  Sauder Classic Bookcase, Traditional                     10672.073
# 6  Harbour Creations Executive Leather Armchair, Adjustable 10427.326
# 7  Nokia Smart Phone, Full Size                              9938.195
# 8  Cisco Smart Phone, with Caller ID                         9786.641
# 9  Nokia Smart Phone, with Caller ID                         9465.326
# 10 Belkin Router, USB                                        8955.018
#    total_sales n_orders
# 1  61599.82     5
# 2  76441.53    38
# 3  73156.30    38
# 4  31663.78    15
# 5  39108.30    29
# 6  50121.52    39
# 7  71904.56    47
# 8  43127.50    27
# 9  47877.79    24
# 10 23470.41    32
#    product_name                                             total_profit
# 1  Lesro Training Table, Rectangular                        -2581.283
# 2  Bevis Wood Table, with Bottom Storage                    -2782.588
# 3  Chromcraft Bull-Nose Wood Oval Conference Tables & Bases -2876.116
# 4  Rogers Lockers, Blue                                     -2893.491
# 5  Bevis Computer Table, Fully Assembled                    -3509.564
# 6  Bevis Round Table, Adjustable Height                     -3649.894
# 7  Cubify CubeX 3D Printer Triple Head Print                -3839.990
# 8  Motorola Smart Phone, Cordless                           -4447.038
# 9  Lexmark MX611dhe Monochrome Laser Printer                -4589.973
# 10 Cubify CubeX 3D Printer Double Head Print                -8879.970
#    total_sales n_orders
# 1   2711.647    5
# 2  11134.662   10
# 3   9917.640    5
# 4  28214.589   42
# 5  11177.896   13
# 6   5654.796    5
# 7   7999.980    1
# 8  38931.042   23
# 9  16829.901    4
# 10 11099.963    3

# %% [markdown]
# ### Which products generate negative profit?

# %%
negative_product_profit <- orders |>  
    group_by(product_name, sub_category, category) |>  
    summarise(    
        total_profit = sum(profit),    
        total_sales = sum(sales),    
        n_orders = n(),    
        .groups = "drop"  
    ) |>  
    filter(    
        total_profit <= 0  
    ) |>  
    arrange(desc(total_profit))

negative_product_profit
# Out:
#     product_name
# 1   Alliance Big Bands Rubber Bands, 12/Pack
# 2   Belkin OmniView SE Rackmount Kit
# 3   Global Super Steno Chair
# 4   Premier Electric Letter Opener
# 5   Stiletto Ruler, Serrated
# 6   Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 9 1/2" X 11"
# 7   Rubber Band Ball
# 8   Brites Rubber Bands, 1 1/2 oz. Box
# 9   Eldon Gobal File Keepers
# 10  Hon Color Coded Labels, Adjustable
# 11  Avery Framed View Binder, EZD Ring (Locking), Navy, 1 1/2"
# 12  Round Ring Binders
# 13  Executive Impressions 16-1/2" Circular Wall Clock
# 14  Hon Chairmat, Black
# 15  SanDisk Cruzer 8 GB USB Flash Drive
# 16  Cameo Clasp Envelope, Recycled
# 17  Acme Serrated Blade Letter Opener
# 18  Executive Impressions 14" Contract Wall Clock with Quartz Movement
# 19  Penpower WorldCard Pro Card Scanner
# 20  Angle-D Ring Binders
# 21  Storex Flexible Poly Binders with Double Pockets
# 22  Computer Printout Index Tabs
# 23  Kingston Digital DataTraveler 8GB USB 2.0
# 24  PNY Rapid USB Car Charger - Black
# 25  Avery Self-Adhesive Photo Pockets for Polaroid Photos
# 26  GBC Twin Loop Wire Binding Elements, 9/16" Spine, Black
# 27  Smead Folders, Wire Frame
# 28  OIC Clamps, Assorted Sizes
# 29  Hoover Commercial Lightweight Upright Vacuum
# 30  Super Bands, 12/Pack
# ⋮   ⋮
# 650 Chromcraft Round Table, Fully Assembled
# 651 SAFCO Executive Leather Armchair, Red
# 652 Barricks Conference Table, with Bottom Storage
# 653 Chromcraft Conference Table, with Bottom Storage
# 654 GBC DocuBind P400 Electric Binding System
# 655 Barricks Round Table, Adjustable Height
# 656 Hon Conference Table, Rectangular
# 657 Barricks Conference Table, Adjustable Height
# 658 Bush Advantage Collection Racetrack Conference Table
# 659 Bush Library with Doors, Pine
# 660 Chromcraft Coffee Table, Fully Assembled
# 661 Safco Library with Doors, Traditional
# 662 Hoover Stove, Silver
# 663 Samsung Audio Dock, with Caller ID
# 664 Hoover Stove, White
# 665 Eldon Lockers, Blue
# 666 Lesro Computer Table, Fully Assembled
# 667 Lesro Round Table, Adjustable Height
# 668 Bevis Conference Table, Fully Assembled
# 669 Barricks Conference Table, Rectangular
# 670 Lesro Training Table, Rectangular
# 671 Bevis Wood Table, with Bottom Storage
# 672 Chromcraft Bull-Nose Wood Oval Conference Tables & Bases
# 673 Rogers Lockers, Blue
# 674 Bevis Computer Table, Fully Assembled
# 675 Bevis Round Table, Adjustable Height
# 676 Cubify CubeX 3D Printer Triple Head Print
# 677 Motorola Smart Phone, Cordless
# 678 Lexmark MX611dhe Monochrome Laser Printer
# 679 Cubify CubeX 3D Printer Double Head Print
#     sub_category category        total_profit total_sales n_orders
# 1   Fasteners    Office Supplies  0.00000e+00   29.7000    4
# 2   Storage      Office Supplies  0.00000e+00  248.3600    2
# 3   Chairs       Furniture       -1.98952e-13 2389.9020    7
# 4   Supplies     Office Supplies -1.98952e-13 2641.6080    8
# 5   Supplies     Office Supplies -1.37400e-01  607.6026   14
# 6   Binders      Office Supplies -1.61400e-01   62.9460    4
# 7   Fasteners    Office Supplies -2.99200e-01   58.3440    4
# 8   Fasteners    Office Supplies -5.14800e-01   13.0680    3
# 9   Storage      Office Supplies -6.05600e-01  348.2200    6
# 10  Labels       Office Supplies -6.14700e-01  479.4153   20
# 11  Binders      Office Supplies -6.98600e-01   99.8000    6
# 12  Binders      Office Supplies -9.15200e-01   29.9520    6
# 13  Furnishings  Furniture       -1.06880e+00   58.7840    2
# 14  Chairs       Furniture       -1.19400e+00 2881.2060   13
# 15  Accessories  Technology      -1.35840e+00   27.1680    1
# 16  Envelopes    Office Supplies -1.66750e+00  538.0725   25
# 17  Supplies     Office Supplies -1.74900e+00   13.9920    2
# 18  Furnishings  Furniture       -1.77840e+00   97.8120    2
# 19  Machines     Technology      -1.82950e+00   91.4750    1
# 20  Binders      Office Supplies -1.96920e+00   39.3840    6
# 21  Binders      Office Supplies -2.00640e+00   10.8240    3
# 22  Binders      Office Supplies -2.01600e+00   11.0880    4
# 23  Accessories  Technology      -2.02300e+00   44.0300    3
# 24  Phones       Technology      -2.07740e+00    9.5880    1
# 25  Binders      Office Supplies -2.17920e+00  143.0100   11
# 26  Binders      Office Supplies -2.28300e+00  269.3940    9
# 27  Storage      Office Supplies -2.35680e+00 1725.8832   36
# 28  Fasteners    Office Supplies -2.44800e+00  354.7320    9
# 29  Appliances   Office Supplies -2.50560e+00   18.0960    2
# 30  Fasteners    Office Supplies -2.60400e+00   33.4800    4
# ⋮   ⋮            ⋮               ⋮            ⋮           ⋮
# 650 Tables       Furniture       -1823.079     3576.751    3
# 651 Chairs       Furniture       -1833.173    25640.127   21
# 652 Tables       Furniture       -1838.370     6500.740    5
# 653 Tables       Furniture       -1850.331    13700.919    9
# 654 Binders      Office Supplies -1878.166    17965.068    6
# 655 Tables       Furniture       -1880.675     3232.075    3
# 656 Tables       Furniture       -1920.851     7588.289    6
# 657 Tables       Furniture       -1924.852     6425.508    5
# 658 Tables       Furniture       -1934.398     9544.725    7
# 659 Bookcases    Furniture       -1949.628     9028.392   11
# 660 Tables       Furniture       -1960.696     1226.424    4
# 661 Bookcases    Furniture       -1972.904    11997.736   15
# 662 Appliances   Office Supplies -2093.086    10316.164    8
# 663 Phones       Technology      -2137.224     7661.946   20
# 664 Appliances   Office Supplies -2180.626    32842.604   18
# 665 Storage      Office Supplies -2181.096    19255.324   36
# 666 Tables       Furniture       -2322.838     7223.262    7
# 667 Tables       Furniture       -2402.976     3960.624    5
# 668 Tables       Furniture       -2443.089    14886.951    8
# 669 Tables       Furniture       -2487.967     3663.832    3
# 670 Tables       Furniture       -2581.283     2711.647    5
# 671 Tables       Furniture       -2782.588    11134.662   10
# 672 Tables       Furniture       -2876.116     9917.640    5
# 673 Storage      Office Supplies -2893.491    28214.589   42
# 674 Tables       Furniture       -3509.564    11177.896   13
# 675 Tables       Furniture       -3649.894     5654.796    5
# 676 Machines     Technology      -3839.990     7999.980    1
# 677 Phones       Technology      -4447.038    38931.042   23
# 678 Machines     Technology      -4589.973    16829.901    4
# 679 Machines     Technology      -8879.970    11099.963    3

# %%
negative_subcategory_profit <- negative_product_profit |>
    group_by(sub_category) |>
    summarise(
        subcategory_profit = sum(total_profit),
        subcategory_sales = sum(total_sales),
        total_orders = sum(n_orders),
        n_products = n(),
        .groups = "drop"
    ) |>
    arrange(desc(subcategory_profit))

negative_subcategory_profit
# Out:
#    sub_category subcategory_profit subcategory_sales total_orders n_products
# 1  Labels         -369.8314          5662.369         241          13
# 2  Fasteners      -806.0523         14325.482         404          25
# 3  Paper         -1163.7703         14396.590         217          12
# 4  Envelopes     -1296.9348         19005.685         295          16
# 5  Art           -3418.5826         39255.227         417          13
# 6  Supplies      -3886.2656         81808.482         489          34
# 7  Binders       -5148.3845         53532.806         673          59
# 8  Accessories   -6236.6255         57933.327         343          24
# 9  Copiers       -7355.9894        159641.041         262          14
# 10 Furnishings   -8129.9257         84674.650         572          48
# 11 Appliances   -11755.9581        158862.651         273          34
# 12 Phones       -13731.9651        195195.756         438          43
# 13 Chairs       -17773.5462        278031.414         843          52
# 14 Storage      -18886.9388        287076.285        1287          68
# 15 Bookcases    -19256.3782        255159.476         479          52
# 16 Machines     -36508.8247        262446.355         459          58
# 17 Tables       -92117.4311        472770.196         603         114

# %% [markdown]
# ### How does profitability compare across product categories and sub-categories?

# %%
category_profit <- orders |>  
    group_by(category) |>  
    summarise(    
        total_profit = sum(profit),    
        total_sales = sum(sales),    
        profit_margin = total_profit / total_sales,    
        .groups = "drop"  
    ) |>  
    arrange(desc(total_profit))

category_profit
# Out:
#   category        total_profit total_sales profit_margin
# 1 Technology      663778.7     4744557     0.13990319
# 2 Office Supplies 518473.8     3787070     0.13690632
# 3 Furniture       286782.3     4110874     0.06976187

# %%
sub_category_sales_profit <- orders |>  
    group_by(sub_category) |>  
    summarise(    
        total_sales = sum(sales),    
        total_profit = sum(profit),    
        profit_margin = total_profit / total_sales,    
        .groups = "drop"  
    ) |>  
    arrange(profit_margin)

sub_category_sales_profit
# Out:
#    sub_category total_sales total_profit profit_margin
# 1  Tables        757041.92  -64083.39    -0.08464972
# 2  Machines      779060.07   58867.87     0.07556269
# 3  Supplies      243074.22   22583.26     0.09290686
# 4  Chairs       1501681.76  141973.80     0.09454320
# 5  Storage      1127085.86  108461.49     0.09623179
# 6  Bookcases    1466572.24  161924.42     0.11041012
# 7  Furnishings   385578.26   46967.43     0.12181036
# 8  Phones       1706824.14  216717.01     0.12697091
# 9  Fasteners      83242.32   11525.42     0.13845631
# 10 Appliances   1011064.30  141680.59     0.14013015
# 11 Art           372091.97   57953.91     0.15575158
# 12 Binders       461911.51   72449.85     0.15684789
# 13 Copiers      1509436.27  258567.55     0.17130074
# 14 Accessories   749237.02  129626.31     0.17301108
# 15 Envelopes     170904.30   29601.12     0.17320287
# 16 Labels         73404.03   15010.51     0.20449166
# 17 Paper         244291.72   59207.68     0.24236467

# %% [markdown]
# # Lifecycle & Time

# %% [markdown]
# ### Do top products show declining or improving performance over time?

# %%
orders_with_period <- orders |>  
    add_time_period("order_date", period = "year")

top_products <- product_sales |>  
    arrange(desc(total_sales)) |>  
    slice_head(n = 10) |>  
    pull(product_name)

product_time_sales <- orders_with_period |>  
    filter(product_name %in% top_products) |>  
    group_by(product_name, period) |>  
    summarise(    
        total_sales = sum(sales, na.rm = TRUE),    
        .groups = "drop"  
    )

product_time_sales
# Out:
#    product_name                                             period
# 1  Apple Smart Phone, Full Size                             2011-01-01
# 2  Apple Smart Phone, Full Size                             2012-01-01
# 3  Apple Smart Phone, Full Size                             2013-01-01
# 4  Apple Smart Phone, Full Size                             2014-01-01
# 5  Canon imageCLASS 2200 Advanced Copier                    2013-01-01
# 6  Canon imageCLASS 2200 Advanced Copier                    2014-01-01
# 7  Cisco Smart Phone, Full Size                             2011-01-01
# 8  Cisco Smart Phone, Full Size                             2012-01-01
# 9  Cisco Smart Phone, Full Size                             2013-01-01
# 10 Cisco Smart Phone, Full Size                             2014-01-01
# 11 Harbour Creations Executive Leather Armchair, Adjustable 2011-01-01
# 12 Harbour Creations Executive Leather Armchair, Adjustable 2012-01-01
# 13 Harbour Creations Executive Leather Armchair, Adjustable 2013-01-01
# 14 Harbour Creations Executive Leather Armchair, Adjustable 2014-01-01
# 15 Hon Executive Leather Armchair, Adjustable               2011-01-01
# 16 Hon Executive Leather Armchair, Adjustable               2012-01-01
# 17 Hon Executive Leather Armchair, Adjustable               2013-01-01
# 18 Hon Executive Leather Armchair, Adjustable               2014-01-01
# 19 Motorola Smart Phone, Full Size                          2011-01-01
# 20 Motorola Smart Phone, Full Size                          2012-01-01
# 21 Motorola Smart Phone, Full Size                          2013-01-01
# 22 Motorola Smart Phone, Full Size                          2014-01-01
# 23 Nokia Smart Phone, Full Size                             2011-01-01
# 24 Nokia Smart Phone, Full Size                             2012-01-01
# 25 Nokia Smart Phone, Full Size                             2013-01-01
# 26 Nokia Smart Phone, Full Size                             2014-01-01
# 27 Nokia Smart Phone, with Caller ID                        2011-01-01
# 28 Nokia Smart Phone, with Caller ID                        2012-01-01
# 29 Nokia Smart Phone, with Caller ID                        2013-01-01
# 30 Nokia Smart Phone, with Caller ID                        2014-01-01
# 31 Office Star Executive Leather Armchair, Adjustable       2011-01-01
# 32 Office Star Executive Leather Armchair, Adjustable       2012-01-01
# 33 Office Star Executive Leather Armchair, Adjustable       2013-01-01
# 34 Office Star Executive Leather Armchair, Adjustable       2014-01-01
# 35 Samsung Smart Phone, Cordless                            2011-01-01
# 36 Samsung Smart Phone, Cordless                            2012-01-01
# 37 Samsung Smart Phone, Cordless                            2013-01-01
# 38 Samsung Smart Phone, Cordless                            2014-01-01
#    total_sales
# 1  14986.246
# 2  19541.873
# 3  21120.408
# 4  31287.252
# 5  25899.926
# 6  35699.898
# 7   6662.650
# 8  11793.170
# 9  26737.133
# 10 31248.578
# 11  7866.978
# 12  7111.396
# 13 21871.130
# 14 13272.012
# 15  4121.910
# 16  7565.760
# 17 20104.603
# 18 26401.211
# 19  5827.916
# 20 10414.182
# 21 29357.098
# 22 27557.107
# 23 16265.523
# 24 21099.527
# 25 14765.880
# 26 19773.626
# 27 10669.797
# 28  9481.424
# 29 18568.854
# 30  9157.710
# 31  6078.456
# 32  9194.368
# 33 19936.146
# 34 15452.714
# 35 14300.820
# 36 11928.000
# 37  8952.390
# 38 13472.250
