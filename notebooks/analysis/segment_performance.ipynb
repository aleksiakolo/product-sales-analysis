# %%
# load required libraries
library(tidyverse)
library(janitor)
library(dplyr)
library(ggplot2)
library(skimr)
library(purrr)
library(lubridate)

source("../../R/apply_factors.R")
source("../../R/analysis_helpers.R")
source("../../R/temporal_helpers.R")
tables <- list(
  Orders   = readr::read_csv("../../data/processed/Orders.csv"),
  Returns  = readr::read_csv("../../data/processed/Returns.csv"),
  People   = readr::read_csv("../../data/processed/People.csv")
)
tables <- apply_factors(tables)
orders <- tables$Orders 
returns <- tables$Returns
people <- tables$People
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.6
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.1     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
# Rows: 51290 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): order_id, ship_mode, customer_name, segment, state, country, mark...
# dbl   (6): sales, quantity, discount, profit, shipping_cost, year
# date  (2): order_date, ship_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1173 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): order_id, market
# lgl (1): returned
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): person, region
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # General Segment Performance

# %% [markdown]
# ### Q1. How do total sales and order volume differ across segments?

# %%
segment_overview <- orders %>%
    group_by(segment) %>%
    summarise(
        total_sales = sum(sales),
        n_orders = n(),
        .groups = "drop"
    ) %>%
    arrange(desc(total_sales))

segment_overview
# Out:
#   segment     total_sales n_orders
# 1 Consumer    6507949     26518
# 2 Corporate   3824698     15429
# 3 Home Office 2309855      9343

# %% [markdown]
# ### Q2. How do average order values vary across segments?

# %%
segment_aov <- orders %>%
    group_by(segment) %>%
    summarise(
        total_sales = sum(sales),
        n_orders = n(),
        avg_order_value = total_sales / n_orders,
        .groups = "drop"
    ) %>%
    arrange(desc(avg_order_value))

segment_aov
# Out:
#   segment     total_sales n_orders avg_order_value
# 1 Corporate   3824698     15429    247.8902
# 2 Home Office 2309855      9343    247.2284
# 3 Consumer    6507949     26518    245.4163

# %% [markdown]
# # Category Preferences by Segment

# %% [markdown]
# ### Q3. Which product categories dominate sales within each segment?

# %%
segment_category_sales <- orders %>%
    group_by(segment, category) %>%
    summarise(
        total_sales = sum(sales),
        .groups = "drop"
    ) %>%
    group_by(segment) %>%
    mutate(
        category_share = total_sales / sum(total_sales)
    ) %>%
    arrange(segment, desc(category_share))

segment_category_sales
# Out:
#   segment     category        total_sales category_share
# 1 Consumer    Technology      2427040.0   0.3729347
# 2 Consumer    Furniture       2128395.8   0.3270455
# 3 Consumer    Office Supplies 1952513.6   0.3000198
# 4 Corporate   Technology      1417791.4   0.3706937
# 5 Corporate   Furniture       1264519.8   0.3306196
# 6 Corporate   Office Supplies 1142386.4   0.2986867
# 7 Home Office Technology       899726.1   0.3895163
# 8 Home Office Furniture        717958.6   0.3108241
# 9 Home Office Office Supplies  692170.2   0.2996596

# %% [markdown]
# ### Q4. Are certain sub-categories important for specific segments?

# %%
segment_subcategory_sales <- orders %>%
    group_by(segment, category, sub_category) %>%
    summarise(
        total_sales = sum(sales),
        .groups = "drop"
    ) %>%
    group_by(segment) %>%
    mutate(
        subcategory_share = total_sales / sum(total_sales)
    ) %>%
    arrange(segment, desc(subcategory_share))

segment_subcategory_sales
# Out:
#    segment     category        sub_category total_sales subcategory_share
# 1  Consumer    Technology      Phones       905422.28   0.139125587
# 2  Consumer    Furniture       Chairs       778362.53   0.119601810
# 3  Consumer    Furniture       Bookcases    765111.14   0.117565626
# 4  Consumer    Technology      Copiers      757081.42   0.116331792
# 5  Consumer    Office Supplies Storage      575506.16   0.088431258
# 6  Consumer    Office Supplies Appliances   510230.28   0.078401083
# 7  Consumer    Technology      Machines     382373.05   0.058754766
# 8  Consumer    Technology      Accessories  382163.27   0.058722532
# 9  Consumer    Furniture       Tables       381726.98   0.058655492
# 10 Consumer    Office Supplies Binders      253745.11   0.038990025
# 11 Consumer    Furniture       Furnishings  203195.11   0.031222602
# 12 Consumer    Office Supplies Art          200870.61   0.030865423
# 13 Consumer    Office Supplies Supplies     123260.31   0.018939961
# 14 Consumer    Office Supplies Paper        119654.78   0.018385942
# 15 Consumer    Office Supplies Envelopes     88473.95   0.013594750
# 16 Consumer    Office Supplies Fasteners     42074.41   0.006465079
# 17 Consumer    Office Supplies Labels        38698.04   0.005946272
# 18 Corporate   Technology      Phones       494085.58   0.129182917
# 19 Corporate   Technology      Copiers      462774.32   0.120996318
# 20 Corporate   Furniture       Bookcases    457327.17   0.119572114
# 21 Corporate   Furniture       Chairs       448519.51   0.117269277
# 22 Corporate   Office Supplies Storage      340019.36   0.088900981
# 23 Corporate   Office Supplies Appliances   317655.41   0.083053735
# 24 Corporate   Furniture       Tables       245793.70   0.064264874
# 25 Corporate   Technology      Accessories  231023.70   0.060403129
# 26 Corporate   Technology      Machines     229907.76   0.060111357
# 27 Corporate   Office Supplies Binders      128534.33   0.033606403
# 28 Corporate   Furniture       Furnishings  112879.40   0.029513289
# 29 Corporate   Office Supplies Art          103571.38   0.027079626
# 30 Corporate   Office Supplies Supplies      81486.40   0.021305318
# 31 Corporate   Office Supplies Paper         71982.55   0.018820454
# 32 Corporate   Office Supplies Envelopes     51805.80   0.013545072
# 33 Corporate   Office Supplies Fasteners     26138.42   0.006834113
# 34 Corporate   Office Supplies Labels        21192.73   0.005541022
# 35 Home Office Technology      Phones       307316.27   0.133045700
# 36 Home Office Technology      Copiers      289580.54   0.125367411
# 37 Home Office Furniture       Chairs       274799.72   0.118968388
# 38 Home Office Furniture       Bookcases    244133.93   0.105692319
# 39 Home Office Office Supplies Storage      211560.34   0.091590314
# 40 Home Office Office Supplies Appliances   183178.61   0.079303078
# 41 Home Office Technology      Machines     166779.26   0.072203349
# 42 Home Office Technology      Accessories  136050.06   0.058899826
# 43 Home Office Furniture       Tables       129521.24   0.056073323
# 44 Home Office Office Supplies Binders       79632.07   0.034474922
# 45 Home Office Furniture       Furnishings   69503.74   0.030090087
# 46 Home Office Office Supplies Art           67649.97   0.029287542
# 47 Home Office Office Supplies Paper         52654.39   0.022795542
# 48 Home Office Office Supplies Supplies      38327.52   0.016593041
# 49 Home Office Office Supplies Envelopes     30624.55   0.013258213
# 50 Home Office Office Supplies Fasteners     15029.49   0.006506682
# 51 Home Office Office Supplies Labels        13513.26   0.005850264

# %% [markdown]
# # Volume vs Value

# %% [markdown]
# ### Q5. Are some segments volume-driven while others are value-driven?

# %%
segment_volume_value <- orders %>%
    group_by(segment) %>%
    summarise(
        total_sales = sum(sales),
        n_orders = n(),
        avg_order_value = total_sales / n_orders,
        .groups = "drop"
    )

segment_volume_value
# Out:
#   segment     total_sales n_orders avg_order_value
# 1 Consumer    6507949     26518    245.4163
# 2 Corporate   3824698     15429    247.8902
# 3 Home Office 2309855      9343    247.2284

# %% [markdown]
# ### Q6. Do segments differ in order frequency per customer?

# %%
segment_order_frequency <- orders %>%
    group_by(segment, customer_name) %>%
    summarise(
      customer_orders = n(),
      .groups = "drop"
    ) %>%
    group_by(segment) %>%
    summarise(
      avg_orders_per_customer = mean(customer_orders),
      median_orders_per_customer = median(customer_orders),
      .groups = "drop"
    )

segment_order_frequency
# Out:
#   segment     avg_orders_per_customer median_orders_per_customer
# 1 Consumer    64.83619                65.0
# 2 Corporate   64.82773                63.0
# 3 Home Office 63.12838                62.5

# %% [markdown]
# # Geographic Interaction

# %% [markdown]
# ### Q7. Do segments exhibit different purchasing patterns across regions?

# %%
segment_region_sales <- orders %>%
    group_by(region, segment) %>%
    summarise(
        total_sales = sum(sales, na.rm = TRUE),
        .groups = "drop"
    ) %>%
    group_by(region) %>%
    mutate(
        segment_share = total_sales / sum(total_sales)
    ) %>%
    arrange(region, desc(segment_share))

segment_region_sales
# Out:
#    region         segment     total_sales segment_share
# 1  Africa         Consumer     423766.81  0.5406753
# 2  Africa         Corporate    204938.95  0.2614774
# 3  Africa         Home Office  155067.45  0.1978473
# 4  Canada         Consumer      35719.11  0.5336932
# 5  Canada         Corporate     19313.73  0.2885740
# 6  Canada         Home Office   11895.33  0.1777328
# 7  Caribbean      Consumer     162349.21  0.5006438
# 8  Caribbean      Corporate    104537.86  0.3223683
# 9  Caribbean      Home Office   57393.80  0.1769879
# 10 Central        Consumer    1479981.17  0.5243879
# 11 Central        Corporate    850363.90  0.3013015
# 12 Central        Home Office  491957.45  0.1743107
# 13 Central Asia   Consumer     369055.49  0.4902264
# 14 Central Asia   Corporate    235540.37  0.3128747
# 15 Central Asia   Home Office  148230.71  0.1968989
# 16 East           Consumer     350908.17  0.5169680
# 17 East           Corporate    200409.35  0.2952488
# 18 East           Home Office  127463.73  0.1877832
# 19 EMEA           Consumer     406745.18  0.5045457
# 20 EMEA           Corporate    250571.39  0.3108204
# 21 EMEA           Home Office  148844.73  0.1846339
# 22 North          Consumer     643955.14  0.5159212
# 23 North          Corporate    394226.15  0.3158444
# 24 North          Home Office  209984.31  0.1682343
# 25 North Asia     Consumer     407394.92  0.4802431
# 26 North Asia     Corporate    265747.33  0.3132668
# 27 North Asia     Home Office  175167.53  0.2064901
# 28 Oceania        Consumer     579550.47  0.5267757
# 29 Oceania        Corporate    322826.91  0.2934298
# 30 Oceania        Home Office  197807.23  0.1797946
# 31 South          Consumer     824890.16  0.5152642
# 32 South          Corporate    496014.60  0.3098335
# 33 South          Home Office  280002.28  0.1749023
# 34 Southeast Asia Consumer     460752.82  0.5209642
# 35 Southeast Asia Corporate    254351.71  0.2875905
# 36 Southeast Asia Home Office  169318.65  0.1914453
# 37 West           Consumer     362880.77  0.5002093
# 38 West           Corporate    225855.27  0.3113279
# 39 West           Home Office  136721.78  0.1884628

# %% [markdown]
# # Stability & Underperformance

# %% [markdown]
# ### Q8. Is any segment consistently underperforming across regions or categories?

# %%
segment_region_performance <- orders %>%
    group_by(segment, region) %>%
    summarise(
        total_sales = sum(sales),
        .groups = "drop"
    ) %>%
    group_by(segment) %>%
    summarise(
        mean_sales = mean(total_sales),
        sd_sales = sd(total_sales),
        cv_sales = sd_sales / mean_sales,
        .groups = "drop"
    )

segment_region_performance
# Out:
#   segment     mean_sales sd_sales cv_sales
# 1 Consumer    500611.5   354180.8 0.7074964
# 2 Corporate   294207.5   204447.1 0.6949078
# 3 Home Office 177681.2   115154.9 0.6480983

# %%
segment_category_performance <- orders %>%
  group_by(segment, category) %>%
  summarise(
    total_sales = sum(sales, na.rm = TRUE),
    .groups = "drop"
  ) %>%
  group_by(segment) %>%
  summarise(
    mean_sales = mean(total_sales),
    sd_sales = sd(total_sales),
    cv_sales = sd_sales / mean_sales,
    .groups = "drop"
  )

segment_category_performance
