# %% [markdown]
# # Inferential Statistics — Geographic Performance
#
# ## Purpose
#
# In this notebook we want to test whether geographic grouping (region/market) is associated with key outcomes (returns, profit sensitivity to discounting).
# This notebook focuses on **inference** (hypothesis tests + simple models) rather than purely descriptive ranking.
#
# **Key questions.**
# 1) Is return probability independent of region?
# 2) Does discount sensitivity (effect of discount on profit) differ by region?
#
# **Outputs.**
# - Test results (χ² test; regression summaries)
# - Effect-size tables (return rate / odds ratios; discount slope by region)
# - Diagnostic plots (pred vs actual, residuals; minimal color palette)
#
# ## Contents
# 1. [Setup and Data Preparation](#1-setup-and-data-preparation)
# 2. [Profit Margin by Region](#2-profit-margin-by-region)
# 3. [Return Rate by Region/Market](#3-return-rate-by-region--market)
# 4. [Discount sensitivity of profit by region](#4-discount-sensitivity-of-profit-by-region)
# 5. [Interpretation](#5-interpretation)

# %% [markdown]
# ## 1. Setup and Data Preparation

# %%
# Load required libraries
library(tidyverse)
library(janitor)
library(dplyr)
library(ggplot2)
library(skimr)
library(purrr)
library(lubridate)

# Source helper scripts
source("../../R/apply_factors.R")
source("../../R/analysis_helpers.R")
source("../../R/temporal_helpers.R")

# Load data
tables <- list(
  Orders  = readr::read_csv("../../data/processed/Orders.csv"),
  Returns = readr::read_csv("../../data/processed/Returns.csv"),
  People  = readr::read_csv("../../data/processed/People.csv")
)

# Apply factor transformations
tables <- apply_factors(tables)

# Extract tables
orders  <- tables$Orders
returns <- tables$Returns
people  <- tables$People

orders <- orders |> mutate(margin = if_else(sales > 0, profit / sales, NA_real_))

returns_one <- returns |>
    transmute(order_id, returned = as.integer(returned)) |>
    group_by(order_id) |>
    summarise(returned = as.integer(any(returned == TRUE)), .groups = "drop")

orders_ret <- orders |>
    left_join(returns_one, by = "order_id") |>
    mutate(returned = replace_na(returned, 0L))
# Out:
# Rows: 51290 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): order_id, ship_mode, customer_name, segment, state, country, mark...
# dbl   (6): sales, quantity, discount, profit, shipping_cost, year
# date  (2): order_date, ship_date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1173 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): order_id, market
# lgl (1): returned
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 14 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): person, region
#
# ...

# %%
theme_set(
    theme_minimal(base_size = 13) +
        theme(
          plot.title = element_text(size = 18, face = "bold"),
          plot.subtitle = element_text(size = 14),
          axis.title = element_text(size = 16),
          axis.text = element_text(size = 14),
          strip.text = element_text(size = 14, face = "bold"),
          legend.title = element_text(size = 16),
          legend.text = element_text(size = 14),
          panel.grid.minor = element_blank()
    )
)

# %% [markdown]
# ## 2. Profit Margin by Region
#
# **Inference question**
#
# Do average profit margins differ across regions?
#
# **Model**
#
# One-way ANOVA:
#
# $margin_i = μ + α_region(i) + ε_i$
#
# $H₀$: All regional mean margins are equal.

# %%
# ANOVA
anova_margin_region <- aov(margin ~ region, data = orders)
summary(anova_margin_region)

# Post-hoc
tuk <- TukeyHSD(anova_margin_region)
tuk
# Out:
#                Df Sum Sq Mean Sq F value Pr(>F)
# region         12    646   53.84   263.5 <2e-16 ***
# Residuals   51277  10476    0.20
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = margin ~ region, data = orders)
#
# $region
#                                     diff           lwr          upr     p adj
# Canada-Africa                0.391147682  0.3116029470  0.470692418 0.0000000
# Caribbean-Africa             0.224591249  0.1819835689  0.267198928 0.0000000
# Central-Africa               0.203824483  0.1775480440  0.230100922 0.0000000
# Central Asia-Africa          0.290577081  0.2507837165  0.330370446 0.0000000
# East-Africa                  0.310874680  0.2751535112  0.346595850 0.0000000
# EMEA-Africa                  0.002417171 -0.0281539651  0.032988308 1.0000000
# North-Africa                 0.268892533  0.2379518178  0.299833247 0.0000000
# ...

# %% [markdown]
# **Interpretation**
#
# The ANOVA tests whether average profit margins are equal across regions. Since the p-value is effectively zero, we reject the null hypothesis and conclude that *average margin differs by region* (at least one region mean is different). We then use Tukey’s post-hoc test to identify which specific regional pairs differ while controlling for multiple comparisons.
#
# **Business meaning:** This suggests geography is a meaningful driver of profitability; follow-up actions include identifying (1) the highest-margin regions to prioritize for growth and (2) the lowest-margin regions to audit for pricing, shipping cost structure, discounting practices, or returns.

# %% [markdown]
# ## 3. Return Rate by Region / Market
#
# **Inference question**
#
# Is the probability of an order being returned independent of region?
#
# **Model**
#
# returned ⟂ region

# %%
orders <- orders %>%  left_join(
    returns %>%      
        mutate(returned = 1L),    
        by = "order_id",    
        relationship = "many-to-many"  
    ) %>%  mutate(
        returned = ifelse(is.na(returned), 0L, returned)  
    ) 
# Chi-square test of independence
return_region_table <- table(orders$returned, orders$region)
chisq.test(return_region_table)
# Out:
# 	Pearson's Chi-squared test
#
# data:  return_region_table
# X-squared = 2140, df = 12, p-value < 2.2e-16

# %% [markdown]
# To quantify regional risk differences, we also estimate a logistic regression model with region as a predictor.

# %%
# Logistic regression: return probability by region
return_region_logit <- glm(  
    returned ~ region,  
    data = orders,  
    family = binomial(link = "logit")
)
summary(return_region_logit)
# Out:
# Call:
# glm(formula = returned ~ region, family = binomial(link = "logit"),
#     data = orders)
#
# Coefficients:
#                        Estimate Std. Error z value Pr(>|z|)
# (Intercept)          -1.957e+01  1.588e+02  -0.123    0.902
# regionCanada         -3.596e-08  5.713e+02   0.000    1.000
# regionCaribbean       1.630e+01  1.588e+02   0.103    0.918
# regionCentral         1.672e+01  1.588e+02   0.105    0.916
# regionCentral Asia    1.630e+01  1.588e+02   0.103    0.918
# regionEast            1.668e+01  1.588e+02   0.105    0.916
# regionEMEA           -3.585e-08  2.196e+02   0.000    1.000
# regionNorth           1.763e+01  1.588e+02   0.111    0.912
# regionNorth Asia      1.802e+01  1.588e+02   0.113    0.910
# regionOceania         1.645e+01  1.588e+02   0.104    0.917
# regionSouth           1.669e+01  1.588e+02   0.105    0.916
# regionSoutheast Asia  1.660e+01  1.588e+02   0.105    0.917
# regionWest            1.785e+01  1.588e+02   0.112    0.910
#
# ...

# %% [markdown]
# **Interpretation**
#
# The chi-square test assesses whether return status is independent of region. With a near-zero p-value, we reject independence, meaning *return likelihood varies by region*. To avoid over-interpreting statistical significance in a large dataset, we also report **Cramér’s V** as an effect-size measure (how strong the association is).
#
# **Business meaning:** Regions with elevated return rates should be investigated for fulfillment/shipping reliability, product-market fit, or customer expectations. This can directly impact profitability via reverse logistics and lost revenue.

# %% [markdown]
# ## 4. Discount Sensitivity of Profit by Region
#
# **Inference question**
#
# Does the effect of discounting on profit vary across regions?
#
# **Model**
#
# $profit_i = β0 + β1·discount_i + β2·region_i + β3·(discount_i × region_i) + ε_i$
#
# The interaction term captures regional differences in discount sensitivity.

# %%
# Interaction regression: discount × region
discount_region_lm <- lm(profit ~ discount * region, data = orders)
summary(discount_region_lm)
# Out:
# Call:
# lm(formula = profit ~ discount * region, data = orders)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6469.0   -51.3   -25.6    32.7  8334.9
#
# Coefficients: (1 not defined because of singularities)
#                                Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     49.9511     2.7651  18.065  < 2e-16 ***
# discount                      -195.1224     8.3656 -23.324  < 2e-16 ***
# regionCanada                    -3.5516     8.8570  -0.401   0.6884
# regionCaribbean                 11.5672     5.8950   1.962   0.0497 *
# regionCentral                   15.0779     3.3515   4.499 6.85e-06 ***
# regionCentral Asia              43.2226     4.8005   9.004  < 2e-16 ***
# regionEast                      24.9316     4.7540   5.244 1.57e-07 ***
# regionEMEA                      -0.9937     3.9473  -0.252   0.8012
# regionNorth                     15.5646     3.8890   4.002 6.28e-05 ***
# ...

# %% [markdown]
# **Interpretation**
#
# The baseline discount coefficient reflects how profit changes with discount in the reference region. Significant interaction terms indicate that *discount sensitivity differs by region*—i.e., the profit penalty (or benefit) from discounting is not uniform globally.
#
# **Business meaning:** Discount strategy should be region-aware. Regions with stronger negative discount sensitivity may require tighter discount controls or alternative levers (bundling, targeted promotions, shipping incentives) rather than broad discounts.

# %% [markdown]
# ## 5. Interpretation
#
# - **Margins differ by region** (ANOVA + post-hoc): geography is a meaningful profitability driver.
# - **Returns vary by region/country** (chi-square + effect size): some regions contribute disproportionately to return volume.
# - **Discount sensitivity differs by region** (interaction model): “one-size-fits-all” discounting can hurt profit in specific geographies.
